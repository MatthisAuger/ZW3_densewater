# %% [markdown]
# # Plotting cross Isobath transports

# %%
# %matplotlib inline

import cosima_cookbook as cc
import matplotlib.pyplot as plt
import numpy as np
import netCDF4 as nc
import cartopy.crs as ccrs
import xarray as xr
import cmocean.cm as cmocean
import glob
import cmocean as cm

import logging
logging.captureWarnings(True)
logging.getLogger('py.warnings').setLevel(logging.ERROR)

from dask.distributed import Client

#figdir = '/g/data/v45/akm157/figures/Antarctic_cross_slope/depth_int_heat_trans/'

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:37431' processes=8 threads=48, memory=188.56 GiB>

# %% [markdown]
# ### Open data:

# %%
databases = ['/scratch/jk72/ma3822/access-om2/archive/01deg_jra55_9091ryf/01deg_jra55_9091ryf.db',
             '/g/data/oz91/ma3822/access-om2/archive/01deg_jra55_ryf_ZW3PC1Plus/ZW3PC1Plus.db',
             '/g/data/oz91/ma3822/access-om2/archive/01deg_jra55_ryf_ZW3PC1Minus/ZW3PC1Minus.db',
             '/scratch/jk72/ma3822/access-om2/archive/01deg_jra55_ryf_ZW3PC2Plus/ZW3PC2Plus.db',
             '/g/data/oz91/ma3822/access-om2/archive/01deg_jra55_ryf_ZW3PC2Minus/ZW3PC2Minus.db']


names = ['Neutral', 'PC1Plus', 'PC1Minus', 'PC2Plus', 'PC2Minus']


expts = ['01deg_jra55_9091ryf', '01deg_jra55_ryf_ZW3PC1Plus','01deg_jra55_ryf_ZW3PC1Minus','01deg_jra55_ryf_ZW3PC2Plus','01deg_jra55_ryf_ZW3PC2Minus']


sessions = [cc.database.create_session(database) for database in databases]

# %%
bathymetry = cc.querying.getvar(expts[0], 'ht', sessions[0], n=1)
bathy = bathymetry.sel(yt_ocean = slice(-90,-50)).load()

# %%
from matplotlib import rc
rc('text', usetex=True)
rc('xtick', labelsize=25) 
rc('ytick', labelsize=25) 
rc('axes', labelsize=25)

# %%
def lim_regional(region,ax, bathy):
    land = xr.where(np.isnan(bathy.rename('land')), 1, np.nan)
    land.plot(ax = ax,add_colorbar =False, cmap = "Greys")
    if region == "Ross":
        ax.set_xlim(-200,-130)
        ax.set_ylim(-80,-70)
    if region == "Weddell":
        ax.set_xlim(-80,40)
        ax.set_ylim(-80,-60)
    if region == "Amundsen":
        ax.set_xlim(-140,-70)
        ax.set_ylim(-76,-65)
    if region == "Prydz":
        ax.set_xlim(60,80)
        ax.set_ylim(-70,-63)

# %%
def load_transp_mean(session,expt,n_months):
    # Open pre-processed cross slope transport data:
    # Note this is slow.
    
    path = np.sort(glob.glob('/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/'+expt+'/*.nc'))
    # print(path)
    vol_transp = xr.open_dataset('/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/'+expt+'/vol_trans_across_contour_2180_01.nc')
    
    for i in range(1, n_months):
        try:
            vol_transp = xr.concat([vol_transp, xr.open_dataset(path[i])], dim = 'time')
        except:
            vol_transp = xr.concat([vol_transp, xr.ones_like(vol_transp.isel(time = 0))*np.nan], dim = 'time')
            print(expt, i)
    # vol_transp['time'] = time_tot.values
    return(vol_transp)

# %%
n_month = 48
vol_transp = [load_transp_mean(sessions[x],expts[x],n_month).vol_trans_across_contour_binned for x in range(len(sessions))]
vol_transp_mean = [transp.mean('time') for transp in vol_transp]
# Out:
# 01deg_jra55_ryf_ZW3PC1Plus 36
# 01deg_jra55_ryf_ZW3PC1Plus 37
# 01deg_jra55_ryf_ZW3PC1Plus 38
# 01deg_jra55_ryf_ZW3PC1Plus 39
# 01deg_jra55_ryf_ZW3PC1Plus 40
# 01deg_jra55_ryf_ZW3PC1Plus 41
# 01deg_jra55_ryf_ZW3PC1Plus 42
# 01deg_jra55_ryf_ZW3PC1Plus 43
# 01deg_jra55_ryf_ZW3PC1Plus 44
# 01deg_jra55_ryf_ZW3PC1Plus 45
# 01deg_jra55_ryf_ZW3PC1Plus 46
# 01deg_jra55_ryf_ZW3PC1Plus 47
# 01deg_jra55_ryf_ZW3PC1Minus 36
# 01deg_jra55_ryf_ZW3PC1Minus 37
# 01deg_jra55_ryf_ZW3PC1Minus 38
# 01deg_jra55_ryf_ZW3PC1Minus 39
# 01deg_jra55_ryf_ZW3PC1Minus 40
# 01deg_jra55_ryf_ZW3PC1Minus 41
# 01deg_jra55_ryf_ZW3PC1Minus 42
# 01deg_jra55_ryf_ZW3PC1Minus 43
# 01deg_jra55_ryf_ZW3PC1Minus 44
# 01deg_jra55_ryf_ZW3PC1Minus 45
# 01deg_jra55_ryf_ZW3PC1Minus 46
# 01deg_jra55_ryf_ZW3PC1Minus 47

# %%
lat_terranova = slice(-75.5,-74.5)
lon_terranova = slice(163-360,168-360)
start_time = '2180-01-01' 
end_time   = '2184-01-01' 
salt_PC1plus = cc.querying.getvar(expts[1],'salt',sessions[1], frequency = '1 monthly').chunk('100MB')
salt_control = cc.querying.getvar(expts[0],'salt',sessions[0], frequency = '1 monthly').chunk('100MB')
salt_PC1minus = cc.querying.getvar(expts[2],'salt',sessions[2], frequency = '1 monthly').chunk('100MB')
salt_PC1plus_terranova = salt_PC1plus.sel(xt_ocean = lon_terranova,yt_ocean = lat_terranova, time=slice(start_time,end_time), st_ocean = slice(800,900)).mean(('st_ocean', 'xt_ocean','yt_ocean')).compute()
salt_PCcontrol_terranova = salt_control.sel(xt_ocean = lon_terranova,yt_ocean = lat_terranova, time=slice(start_time,end_time), st_ocean = slice(800,900)).mean(('st_ocean', 'xt_ocean','yt_ocean')).compute()
salt_PC1minus_terranova = salt_PC1minus.sel(xt_ocean = lon_terranova,yt_ocean = lat_terranova, time=slice(start_time,end_time), st_ocean = slice(800,900)).mean(('st_ocean', 'xt_ocean','yt_ocean')).compute()


salt_PC2plus = cc.querying.getvar(expts[3],'salt',sessions[3], frequency = '1 monthly').chunk('100MB')
salt_control = cc.querying.getvar(expts[0],'salt',sessions[0], frequency = '1 monthly').chunk('100MB')
salt_PC2minus = cc.querying.getvar(expts[4],'salt',sessions[4], frequency = '1 monthly').chunk('100MB')
salt_PC2plus_terranova = salt_PC2plus.sel(xt_ocean = lon_terranova,yt_ocean = lat_terranova, time=slice(start_time,end_time), st_ocean = slice(800,900)).mean(('st_ocean', 'xt_ocean','yt_ocean')).compute()
salt_PCcontrol_terranova = salt_control.sel(xt_ocean = lon_terranova,yt_ocean = lat_terranova, time=slice(start_time,end_time), st_ocean = slice(800,900)).mean(('st_ocean', 'xt_ocean','yt_ocean')).compute()
salt_PC2minus_terranova = salt_PC2minus.sel(xt_ocean = lon_terranova,yt_ocean = lat_terranova, time=slice(start_time,end_time), st_ocean = slice(800,900)).mean(('st_ocean', 'xt_ocean','yt_ocean')).compute()

# %%
salt_terranova = [salt_PCcontrol_terranova,salt_PC1plus_terranova,salt_PC1minus_terranova, salt_PC2plus_terranova, salt_PC2minus_terranova]

# %%
session = cc.database.create_session()
expt = '01deg_jra55v13_ryf9091'
salinity_bench = cc.querying.getvar(expt, 'salt', session, frequency='1 monthly',start_time= "2170-01-01", end_time = "2180-01-01") # SST - conservative temperature in K (sheck this is the case for your run)
lat_terranova = slice(-75.5,-74.5)
lon_terranova = slice(163-360,168-360)
salinity_terranova_bench = salinity_bench.sel(xt_ocean = lon_terranova,yt_ocean = lat_terranova, time=slice("2170-01-01","2180-01-01"), st_ocean = slice(800,900)).mean(('st_ocean', 'xt_ocean','yt_ocean')).compute()

# %%
salinity_terranova_bench_mean = salinity_terranova_bench.groupby('time.month').mean().to_numpy()
salinity_terranova_bench_std = salinity_terranova_bench.groupby('time.month').std().to_numpy()
salinity_terranova_bench_mean_36 = np.array(salinity_terranova_bench_mean.tolist()+salinity_terranova_bench_mean.tolist()+salinity_terranova_bench_mean.tolist())
salinity_terranova_bench_std_36 = np.array(salinity_terranova_bench_std.tolist()+salinity_terranova_bench_std.tolist()+salinity_terranova_bench_std.tolist())

# %%
def load_transp_mean_bench(expt):
    # Open pre-processed cross slope transport data:
    # Note this is slow.
    
    path = np.sort(glob.glob('/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/'+expt+'/*.nc'))
    print(path)
    vol_transp = xr.open_dataset('/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/'+expt+'/vol_trans_across_contour_2170_01.nc')
    
    for i in range(1, len(path)):
        try:
            vol_transp = xr.concat([vol_transp, xr.open_dataset(path[i])], dim = 'time')
        except:
            vol_transp = xr.concat([vol_transp, xr.ones_like(vol_transp.isel(time = 0))*np.nan], dim = 'time')
            print(expt, i)
    # vol_transp['time'] = time_tot.values
    return(vol_transp)

# %%
vol_transp_bench = load_transp_mean_bench("01deg_jra55v13_ryf9091").vol_trans_across_contour_binned
import datetime
vol_transp_bench["time"] = np.array([datetime.datetime(1970 + i//12,1+i%12,1) for i in range(len(vol_transp_bench.time))])
# Out:
# ['/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2170_01.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2170_02.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2170_03.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2170_04.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2170_05.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2170_06.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2170_07.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2170_08.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2170_09.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2170_10.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2170_11.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2170_12.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2171_01.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2171_02.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2171_03.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2171_04.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2171_05.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2171_06.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2171_07.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2171_08.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2171_09.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2171_10.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2171_11.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2171_12.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2172_01.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2172_02.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2172_03.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2172_04.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2172_05.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2172_06.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2172_07.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2172_08.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2172_09.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2172_10.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2172_11.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2172_12.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2173_01.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2173_02.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2173_03.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2173_04.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2173_05.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2173_06.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2173_07.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2173_08.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2173_09.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2173_10.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2173_11.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2173_12.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2174_01.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2174_02.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2174_03.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2174_04.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2174_05.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2174_06.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2174_07.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2174_08.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2174_09.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2174_10.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2174_11.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2174_12.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2175_01.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2175_02.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2175_03.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2175_04.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2175_05.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2175_06.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2175_07.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2175_08.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2175_09.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2175_10.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2175_11.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2175_12.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2176_01.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2176_02.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2176_03.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2176_04.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2176_05.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2176_06.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2176_07.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2176_08.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2176_09.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2176_10.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2176_11.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2176_12.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2177_01.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2177_02.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2177_03.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2177_04.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2177_05.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2177_06.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2177_07.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2177_08.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2177_09.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2177_10.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2177_11.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2177_12.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2178_01.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2178_02.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2178_03.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2178_04.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2178_05.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2178_06.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2178_07.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2178_08.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2178_09.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2178_10.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2178_11.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2178_12.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2179_01.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2179_02.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2179_03.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2179_04.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2179_05.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2179_06.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2179_07.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2179_08.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2179_09.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2179_10.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2179_11.nc'
#  '/g/data/jk72/ma3822/data/ZW3_project/runs/ZW3_01/cross_contour_transport/01deg_jra55v13_ryf9091/vol_trans_across_contour_2179_12.nc']

# %%
def lat_lon_contour(session,expt):

    # Compute lat/long along contour:
    
    isobath_depth = 1000
    outfile = '/g/data/jk72/ma3822/data/ZW3_project/Antarctic_contour_1000m.npz'
    data = np.load(outfile)
    mask_y_transport_numbered = data['mask_y_transport_numbered']
    mask_x_transport_numbered = data['mask_x_transport_numbered']
    
    yt_ocean = cc.querying.getvar(expt,'yt_ocean',session,n=1)
    yt_ocean = yt_ocean.sel(yt_ocean=slice(-90,-59))
    yu_ocean = cc.querying.getvar(expt,'yu_ocean',session,n=1)
    yu_ocean = yu_ocean.sel(yu_ocean=slice(-90,-59))
    xt_ocean = cc.querying.getvar(expt,'xt_ocean',session,n=1)
    xu_ocean = cc.querying.getvar(expt,'xu_ocean',session,n=1)
    
    mask_x_transport_numbered = xr.DataArray(mask_x_transport_numbered, coords=[('y_ocean', yt_ocean.data), ('x_ocean', 
    xu_ocean.data)])
    mask_y_transport_numbered = xr.DataArray(mask_y_transport_numbered, coords=[('y_ocean', yu_ocean.data), ('x_ocean', 
    xt_ocean.data)])
    
    # stack contour data into 1d:
    mask_x_numbered_1d = mask_x_transport_numbered.stack(contour_index = ['y_ocean', 'x_ocean'])
    mask_x_numbered_1d = mask_x_numbered_1d.where(mask_x_numbered_1d > 0, drop = True)
    mask_y_numbered_1d = mask_y_transport_numbered.stack(contour_index = ['y_ocean', 'x_ocean'])
    mask_y_numbered_1d = mask_y_numbered_1d.where(mask_y_numbered_1d > 0, drop = True)
    contour_ordering = xr.concat((mask_x_numbered_1d,mask_y_numbered_1d), dim = 'contour_index')
    contour_ordering = contour_ordering.sortby(contour_ordering)
    contour_index_array = np.arange(1,len(contour_ordering)+1)
    
    lat_along_contour = contour_ordering.y_ocean
    lon_along_contour = contour_ordering.x_ocean
    # don't need the multi-index anymore, replace with contour count
    lat_along_contour.coords['contour_index'] = contour_index_array
    lon_along_contour.coords['contour_index'] = contour_index_array
    return(lon_along_contour,lat_along_contour)

# %%
lon_along_contour,lat_along_contour = lat_lon_contour(sessions[0],expts[0])

# %%
vol_transp_bench_ross = vol_transp_bench.where((lon_along_contour>-200)&(lon_along_contour<-160),drop=True).sel(isopycnal_bins = slice(32.56,None)).sum("isopycnal_bins").sum('contour_index')/1e6

# %%
vol_transp_bench_ross_mean = vol_transp_bench_ross.groupby('time.month').mean().to_numpy()
vol_transp_bench_ross_std = vol_transp_bench_ross.groupby('time.month').std().to_numpy()
vol_transp_bench_ross_mean_36 = np.array(vol_transp_bench_ross_mean.tolist()*3)
vol_transp_bench_ross_std_36 = np.array(vol_transp_bench_ross_std.tolist()*3)

# %%
#Ross
import datetime
hov_time_datetime = range(0,36)


colors = ["k", "r", "b"]
alpha = [1,1,1]
endmonth = [36,36,36,48,48]
reg = (lon_along_contour>-200)&(lon_along_contour<-160)
f, axes = plt.subplots(2,1,figsize = (12,4), sharex = True)
ax = axes[0]
for a,i in enumerate([0,1,2]):
    ax.plot(hov_time_datetime,salt_terranova[a][:endmonth[a]], color = colors[a], alpha = alpha[a])
ax.grid()
ax.plot(hov_time_datetime,salinity_terranova_bench_mean_36, color = "grey", alpha = 0.8)
ax.fill_between(hov_time_datetime,salinity_terranova_bench_mean_36 - salinity_terranova_bench_std_36,salinity_terranova_bench_mean_36 + salinity_terranova_bench_std_36 , color = "grey", alpha = 0.2)


ax = axes[1]
region = "Ross"
reg_trans = [vol_transp_var.where((lon_along_contour>-200)&(lon_along_contour<-160),drop=True) for vol_transp_var in vol_transp]
for a,i in enumerate([0,1,2]):
    reg_trans_y = reg_trans[i].sel(isopycnal_bins = slice(32.56,None)).sum("isopycnal_bins").sum('contour_index')/1e6
    ax.plot(hov_time_datetime,reg_trans_y[:endmonth[a]], color = colors[a], alpha = alpha[a])
    
ax.plot(hov_time_datetime,vol_transp_bench_ross_mean_36, color = "grey", alpha = 0.8)
ax.fill_between(hov_time_datetime,vol_transp_bench_ross_mean_36 - vol_transp_bench_ross_std_36,vol_transp_bench_ross_mean_36 + vol_transp_bench_ross_std_36 , color = "grey", alpha = 0.2)
# ax.plot(hov_time_datetime,vol_transp_bench_ross[:len(hov_time_datetime)], color = "grey", alpha = 0.8)


ax.set_xlabel("Months")
ax.grid()
ax.set_xticks(range(0,42,6))
ax.set_xlim(0,35)

# plt.ylabel("cross 1000m DSW transport")
# Out:
# (0.0, 35.0)

# %%
da_agebottom = xr.open_dataarray("/g/data/oz91/ma3822/ZW3/data/agebottom_0_24.nc")
da_swmt_shelf = xr.open_dataarray("/g/data/oz91/ma3822/ZW3/data/swmt_yr12_32_85.nc")

# %%
def shelf_mask_isobath(var):
    '''
    Masks ACCESS-OM2-01 variables by the region polewards of the 1000m isobath as computed using 
    a script contributed by Adele Morrison.
    Only to be used with ACCESS-OM2-0.1 output!
    '''
    contour_file = np.load('/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz')
    
    shelf_mask = contour_file['contour_masked_above']
    yt_ocean = contour_file['yt_ocean']
    xt_ocean = contour_file['xt_ocean']
    
    # in this file the points along the isobath are given a positive value, the points outside (northwards) 
    # of the isobath are given a value of -100 and all the points on the continental shelf have a value of 0 
    # so we mask for the 0 values 
    shelf_mask[np.where(shelf_mask!=0)] = np.nan
    shelf_mask = shelf_mask+1
    shelf_map  = np.nan_to_num(shelf_mask)
    shelf_mask = xr.DataArray(shelf_mask, coords = [('yt_ocean', yt_ocean), ('xt_ocean', xt_ocean)])
    shelf_map  = xr.DataArray(shelf_map,  coords = [('yt_ocean', yt_ocean), ('xt_ocean', xt_ocean)])
    
    # then we want to multiply the variable with the mask so we need to account for the shape of the mask. 
    # The mask uses a northern cutoff of 59S.
    masked_var = var.sel(yt_ocean = slice(-90, -59.03)) * shelf_mask

    return masked_var, shelf_map

# %%
ht = cc.querying.getvar(expt, 'ht', session, n=1) 
ht = ht.sel(yt_ocean = slice(-90, -59))

land_mask = (ht*0).fillna(1)
yt_ocean = ht.yt_ocean.values
xt_ocean = ht.xt_ocean.values
ht_shelf, shelf_mask = shelf_mask_isobath(ht)

# %%
area_t = cc.querying.getvar(expt, 'area_t', session, n=1) # needed for the plots I'll provide.

# %%
# swmt_sum_shelf = []
# swmt_shelf_all = []

area_t_shelf, shelf_mask = shelf_mask_isobath(area_t)
# for i in range(len(expts)):
#     swmt_shelf, shelf_mask = shelf_mask_isobath(swmt_expt_yr12[i])
#     swmt_shelf_all.append(swmt_shelf)
#     swmt_sum_shelf.append((swmt_shelf * area_t_shelf / 1e6).sum(['xt_ocean', 'yt_ocean']).values)

# %%
da_swmt_shelf
# Out:
# <xarray.DataArray (scenario: 5, yt_ocean: 510, xt_ocean: 3600)>
# [9180000 values with dtype=float64]
# Coordinates:
#   * yt_ocean        (yt_ocean) float64 -81.11 -81.07 -81.02 ... -59.08 -59.03
#   * xt_ocean        (xt_ocean) float64 -279.9 -279.8 -279.7 ... 79.85 79.95
#     isopycnal_bins  float64 ...
#   * scenario        (scenario) object 'Neutral' 'PC1Plus' ... 'PC2Minus'

# %%
da_swmt_shelf = xr.open_dataarray("/g/data/oz91/ma3822/ZW3/data/swmt_sig0_yr12.nc").isel(isopycnal_bins = 19)
import matplotlib.colors as col

f, ax = plt.subplots(1,1, figsize = (4,4))



# ax.contour(xt_ocean, yt_ocean,land_mask, [0, 1],
#            colors='k', alpha = 0.3)
ax.contour(shelf_mask.xt_ocean, shelf_mask.yt_ocean, shelf_mask, [0, 1],
           colors='k', alpha =0.8)

norm = col.Normalize(vmin=0, vmax=2.5)


cs = ax.pcolormesh(da_agebottom.xt_ocean, da_agebottom.yt_ocean, da_agebottom.sel(scenario = "PC1Plus") - da_agebottom.sel(scenario = "Neutral"),
                       cmap=cm.cm.balance, vmin=-20, vmax=20)

swmt_loc = da_swmt_shelf
swmt_loc = swmt_loc.where(swmt_loc>0)

plot_swmt = ax.pcolormesh(da_swmt_shelf.xt_ocean, da_swmt_shelf.yt_ocean, swmt_loc.sel(scenario = "PC1Plus"),
                           cmap=cm.cm.matter, vmin = 0, vmax = 2.5*1e-5)
land = xr.where(np.isnan(bathy.rename('land')), 1, np.nan)
land.plot(ax = ax,add_colorbar =False, cmap = "Greys")
lim_regional("Ross", ax,bathy)
ax.set_xlabel(None)
ax.set_ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
from matplotlib import rc
rc('text', usetex=True)
rc('xtick', labelsize=14) 
rc('ytick', labelsize=14) 
rc('axes', labelsize=14)

# %%
southernmost_saltanom_PC1plus = xr.open_dataarray("/g/data/oz91/ma3822/ZW3/data/southernmost_salt_PC1plus_depthweight.nc")

# %%
# f = plt.figure(figsize = (10,10))
# ax1 = plt.subplot2grid((3, 2), (0, 0))
# ax2 = plt.subplot2grid((3, 2), (0, 1))
# ax4 = plt.subplot2grid((3, 2), (2, 0), colspan=2)

# ax3 = plt.subplot2grid((3, 2), (1, 0), colspan=2, sharex=ax4)

# ax = ax1
# ax.contour(shelf_mask.xt_ocean, shelf_mask.yt_ocean, shelf_mask, [0, 1],
#            colors='k', alpha =0.8)

# norm = col.Normalize(vmin=0, vmax=2.5)


# cs = ax.pcolormesh(da_agebottom.xt_ocean, da_agebottom.yt_ocean, da_agebottom.sel(scenario = "PC1Plus") - da_agebottom.sel(scenario = "Neutral"),
#                        cmap=cm.cm.balance, vmin=-20, vmax=20)

# swmt_loc = da_swmt_shelf
# swmt_loc = swmt_loc.where(swmt_loc>0)

# plot_swmt = ax.pcolormesh(da_swmt_shelf.xt_ocean, da_swmt_shelf.yt_ocean, swmt_loc.sel(scenario = "PC1Plus"),
#                            cmap=cm.cm.matter, vmin = 0, vmax = 2.5*1e-5)
# land = xr.where(np.isnan(bathy.rename('land')), 1, np.nan)
# land.plot(ax = ax,add_colorbar =False, cmap = "Greys")
# lim_regional("Ross", ax,bathy)
# ax.set_xlabel(None)
# ax.set_ylabel(None)
# ax.set_ylabel("Latitude (°)")
# ax.set_xlabel("Longitude (°)")

# cbar1 = plt.colorbar(cs, ax = ax1)
# cbar1.set_label(r'Age Bottom Anomaly (years)', rotation=270, labelpad=20, size = 16)

# ax = ax2
# cs = ax.pcolormesh(southernmost_saltanom_PC1plus.xt_ocean_sub01,hov_time_datetime, hov, cmap = cm.cm.balance, vmin = -0.4,vmax = 0.4)
# # ax.colorbar()
# ax.set_yticks([datetime.datetime(1+i//12,1+i%12,1) for i in range(0,30,6)], labels =[r'${}$'.format(i) for i in range(0,30,6)] )
# # ax.set_yticks([datetime.datetime(1+i//12,1+i%12,1) for i in range(0,30,6)])

# ax.grid()
# cbar2 = plt.colorbar(cs, ax = ax2)
# cbar2.set_label(r'Salinity Anomaly (psu)', rotation=270, labelpad=20, size = 16)

# ax.set_ylabel("Months")
# ax.set_xlabel("Longitude (°)")




# #Ross
# import datetime
# hov_time_datetime2 = range(0,36)


# colors = ["k", "r", "b"]
# alpha = [1,1,1]
# endmonth = [36,36,36,48,48]
# reg = (lon_along_contour>-200)&(lon_along_contour<-160)
# ax = ax3
# for a,i in enumerate([0,1,2]):
#     ax.plot(hov_time_datetime2,salt_terranova[a][:endmonth[a]], color = colors[a], alpha = alpha[a])
# ax.grid()
# ax.plot(hov_time_datetime2,salinity_terranova_bench_mean_36, color = "grey", alpha = 0.8)
# ax.fill_between(hov_time_datetime2,salinity_terranova_bench_mean_36 - salinity_terranova_bench_std_36,salinity_terranova_bench_mean_36 + salinity_terranova_bench_std_36 , color = "grey", alpha = 0.2)

# ax.set_ylabel("Salinity (psu)")
# ax3.set_xticklabels([])
# ax = ax4
# region = "Ross"
# reg_trans = [vol_transp_var.where((lon_along_contour>-200)&(lon_along_contour<-160),drop=True) for vol_transp_var in vol_transp]
# for a,i in enumerate([0,1,2]):
#     reg_trans_y = reg_trans[i].sel(isopycnal_bins = slice(32.56,None)).sum("isopycnal_bins").sum('contour_index')/1e6
#     ax.plot(hov_time_datetime2,reg_trans_y[:endmonth[a]], color = colors[a], alpha = alpha[a])
    
# ax.plot(hov_time_datetime2,vol_transp_bench_ross_mean_36, color = "grey", alpha = 0.8)
# ax.fill_between(hov_time_datetime2,vol_transp_bench_ross_mean_36 - vol_transp_bench_ross_std_36,vol_transp_bench_ross_mean_36 + vol_transp_bench_ross_std_36 , color = "grey", alpha = 0.2)
# # ax.plot(hov_time_datetime,vol_transp_bench_ross[:len(hov_time_datetime)], color = "grey", alpha = 0.8)

# ax.set_ylabel("Transport (Sv)")

# ax.set_xlabel("Months")
# ax.grid()
# ax.set_xticks(range(0,42,6))
# ax.set_xlim(0,35)

# # plt.ylabel("cross 1000m DSW transport")
# plt.tight_layout()
# plt.subplots_adjust(hspace=0.15)  # Reduce vertical spacing between subplots

# %%
# import matplotlib.gridspec as gridspec

# f = plt.figure(figsize = (12,8))

# # Create a gridspec with custom spacing
# gs = gridspec.GridSpec(3, 2, 
#                        height_ratios=[1, 1, 1],  # Equal heights for all rows
#                        hspace=0.3)  # Overall vertical spacing

# # Create a gridspec with custom spacing
# gs2 = gridspec.GridSpec(3, 3, 
#                        height_ratios=[1, 1, 1],  # Equal heights for all rows
#                        hspace=0.3)  # Overall vertical spacing

# # Create subplots using gridspec
# ax1 = plt.subplot(gs2[0, 0])
# ax2 = plt.subplot(gs[0, 1])

# # For the bottom two plots, create a sub-gridspec with tighter spacing
# gs_bottom = gridspec.GridSpecFromSubplotSpec(2, 1, gs[1:, :], 
#                                             hspace=0.1)  # Tight spacing between bottom plots

# ax3 = plt.subplot(gs_bottom[0], sharex=ax4)
# ax4 = plt.subplot(gs_bottom[1])


# ax = ax1
# ax.contour(shelf_mask.xt_ocean, shelf_mask.yt_ocean, shelf_mask, [0, 1],
#            colors='k', alpha =0.8)

# norm = col.Normalize(vmin=0, vmax=2.5)


# cs = ax.pcolormesh(da_agebottom.xt_ocean, da_agebottom.yt_ocean, da_agebottom.sel(scenario = "PC1Plus") - da_agebottom.sel(scenario = "Neutral"),
#                        cmap=cm.cm.balance, vmin=-20, vmax=20)

# swmt_loc = da_swmt_shelf
# swmt_loc = swmt_loc.where(swmt_loc>0)

# plot_swmt = ax.pcolormesh(da_swmt_shelf.xt_ocean, da_swmt_shelf.yt_ocean, swmt_loc.sel(scenario = "PC1Plus"),
#                            cmap=cm.cm.matter, vmin = 0, vmax = 2.5*1e-5)
# land = xr.where(np.isnan(bathy.rename('land')), 1, np.nan)
# land.plot(ax = ax,add_colorbar =False, cmap = "Greys")
# lim_regional("Ross", ax,bathy)
# ax.set_xlabel(None)
# ax.set_ylabel(None)
# # ax.set_ylabel("Latitude (°)")
# # ax.set_xlabel("Longitude (°)")

# cbar1 = plt.colorbar(cs, ax = ax1)
# # cbar1.set_label(r'Age Bottom Anomaly (years)', rotation=270, labelpad=20, size = 12)
# # cbar1.set_label(r'Age Bottom Anomaly (years)',  size = 12)

# pos1 = ax1.get_position()
# # Create small axes for SWMT colorbar (positioned in upper left of ax1)
# # cbar_ax_swmt = f.add_axes([pos1.x0 + 0.22, pos1.y1 - 0.14, 0.05, 0.01])  # [left, bottom, width, height]
# # cbar_swmt = plt.colorbar(plot_swmt, cax=cbar_ax_swmt)
# cbar_swmt = plt.colorbar(plot_swmt, ax = ax1)
# # cbar_swmt.set_label(r'Surface Transformation (m/s)',size = 12)

# ax = ax2
# cs = ax.pcolormesh(southernmost_saltanom_PC1plus.xt_ocean_sub01,hov_time_datetime, hov, cmap = cm.cm.balance, vmin = -0.4,vmax = 0.4)
# # ax.colorbar()
# ax.set_yticks([datetime.datetime(1+i//12,1+i%12,1) for i in range(0,30,6)], labels =[r'${}$'.format(i) for i in range(0,30,6)] )
# # ax.set_yticks([datetime.datetime(1+i//12,1+i%12,1) for i in range(0,30,6)])

# ax.grid()
# cbar2 = plt.colorbar(cs, ax = ax2)
# # cbar2.set_label(r'Salinity Anomaly (psu)', rotation=270, labelpad=20, size = 12)

# # ax.set_ylabel("Months")
# # ax.set_xlabel("Longitude (°)")




# #Ross
# import datetime
# hov_time_datetime2 = range(0,36)


# colors = ["k", "r", "b"]
# alpha = [1,1,1]
# endmonth = [36,36,36,48,48]
# reg = (lon_along_contour>-200)&(lon_along_contour<-160)
# ax = ax3
# for a,i in enumerate([0,1,2]):
#     ax.plot(hov_time_datetime2,salt_terranova[a][:endmonth[a]], color = colors[a], alpha = alpha[a])
# ax.grid()
# ax.plot(hov_time_datetime2,salinity_terranova_bench_mean_36, color = "grey", alpha = 0.8)
# ax.fill_between(hov_time_datetime2,salinity_terranova_bench_mean_36 - salinity_terranova_bench_std_36,salinity_terranova_bench_mean_36 + salinity_terranova_bench_std_36 , color = "grey", alpha = 0.2)

# # ax.set_ylabel("Salinity (psu)")
# ax3.set_xticklabels([])
# ax = ax4
# region = "Ross"
# reg_trans = [vol_transp_var.where((lon_along_contour>-200)&(lon_along_contour<-160),drop=True) for vol_transp_var in vol_transp]
# for a,i in enumerate([0,1,2]):
#     reg_trans_y = reg_trans[i].sel(isopycnal_bins = slice(32.56,None)).sum("isopycnal_bins").sum('contour_index')/1e6
#     ax.plot(hov_time_datetime2,reg_trans_y[:endmonth[a]], color = colors[a], alpha = alpha[a])
    
# ax.plot(hov_time_datetime2,vol_transp_bench_ross_mean_36, color = "grey", alpha = 0.8)
# ax.fill_between(hov_time_datetime2,vol_transp_bench_ross_mean_36 - vol_transp_bench_ross_std_36,vol_transp_bench_ross_mean_36 + vol_transp_bench_ross_std_36 , color = "grey", alpha = 0.2)
# # ax.plot(hov_time_datetime,vol_transp_bench_ross[:len(hov_time_datetime)], color = "grey", alpha = 0.8)

# # ax.set_ylabel("Transport (Sv)")

# # ax.set_xlabel("Months")
# ax.grid()
# ax.set_xticks(range(0,42,6))
# ax.set_xlim(0,35)
# ax4.tick_params(labelbottom=True)


# # pos2 = ax2.get_position()

# # # Move ax4 closer to ax3
# # new_left = pos2.x0 + 0.02  # Adjust this value to control spacing
# # ax2.set_position([new_left, pos2.y0, pos2.width, pos2.height])


# # plt.ylabel("cross 1000m DSW transport")
# plt.tight_layout()
# # plt.subplots_adjust(hspace=0.15)  # Reduce vertical spacing between subplots

# %%
southernmost_saltanom_PC1plus
# Out:
# <xarray.DataArray 'southernmost_salt' (time: 882, xt_ocean_sub01: 700)>
# [617400 values with dtype=float64]
# Coordinates:
#   * time            (time) object 2180-01-01 12:00:00 ... 2182-06-01 12:00:00
#   * xt_ocean_sub01  (xt_ocean_sub01) float64 -199.9 -199.8 ... -130.2 -130.1
# Attributes:
#     long_name:    Southernmost valid salinity
#     description:  Salinity at the southernmost non-masked point (determined f...

# %%
import matplotlib.gridspec as gridspec

f = plt.figure(figsize = (12,8))

# Create a gridspec with custom spacing
gs = gridspec.GridSpec(3, 2, 
                       height_ratios=[1, 1, 1],  # Equal heights for all rows
                       hspace=0.3)  # Overall vertical spacing

# Create a gridspec with custom spacing
gs2 = gridspec.GridSpec(3, 3, 
                       height_ratios=[1, 1, 1],  # Equal heights for all rows
                       hspace=0.3)  # Overall vertical spacing

# Create subplots using gridspec
ax1 = plt.subplot(gs2[0, 0])
ax2 = plt.subplot(gs[0, 1])

# For the bottom two plots, create a sub-gridspec with tighter spacing
gs_bottom = gridspec.GridSpecFromSubplotSpec(2, 1, gs[1:, :], 
                                            hspace=0.1)  # Tight spacing between bottom plots

ax4 = plt.subplot(gs_bottom[1])
ax3 = plt.subplot(gs_bottom[0], sharex=ax4)


ax = ax1
ax.contour(shelf_mask.xt_ocean, shelf_mask.yt_ocean, shelf_mask, [0, 1],
           colors='k', alpha =0.8)

norm = col.Normalize(vmin=0, vmax=2.5)


cs = ax.pcolormesh(da_agebottom.xt_ocean, da_agebottom.yt_ocean, da_agebottom.sel(scenario = "PC1Plus") - da_agebottom.sel(scenario = "Neutral"),
                       cmap=cm.cm.balance, vmin=-20, vmax=20)

swmt_loc = da_swmt_shelf
swmt_loc = swmt_loc.where(swmt_loc>0)

plot_swmt = ax.pcolormesh(da_swmt_shelf.xt_ocean, da_swmt_shelf.yt_ocean, swmt_loc.sel(scenario = "PC1Plus"),
                           cmap=cm.cm.matter, vmin = 0, vmax = 2.5*1e-5)
land = xr.where(np.isnan(bathy.rename('land')), 1, np.nan)
land.plot(ax = ax,add_colorbar =False, cmap = "Greys")
lim_regional("Ross", ax,bathy)
ax.set_xlabel(None)
ax.set_ylabel(None)
# ax.set_ylabel("Latitude (°)")
# ax.set_xlabel("Longitude (°)")

# cbar1 = plt.colorbar(cs, ax = ax1)
# cbar1.set_label(r'Age Bottom Anomaly (years)', rotation=270, labelpad=20, size = 12)
# cbar1.set_label(r'Age Bottom Anomaly (years)',  size = 12)

# pos1 = ax1.get_position()
# Create small axes for SWMT colorbar (positioned in upper left of ax1)
# cbar_ax_swmt = f.add_axes([pos1.x0 + 0.22, pos1.y1 - 0.14, 0.05, 0.01])  # [left, bottom, width, height]
# cbar_swmt = plt.colorbar(plot_swmt, cax=cbar_ax_swmt)
# cbar_swmt = plt.colorbar(plot_swmt, ax = ax1)
# cbar_swmt.set_label(r'Surface Transformation (m/s)',size = 12)

ax = ax2
hov = southernmost_saltanom_PC1plus.sel(time = slice("2180-01-01", "2182-01-01"))
hov_time_datetime = [datetime.datetime(1,1,2) + datetime.timedelta(days = i) for i in range(len(hov.time))]

cs = ax.pcolormesh(hov.xt_ocean_sub01,hov_time_datetime, hov, cmap = cm.cm.balance, vmin = -0.4,vmax = 0.4)
# ax.colorbar()
ax.set_yticks([datetime.datetime(1+i//12,1+i%12,1) for i in range(0,30,6)], labels =[r'${}$'.format(i) for i in range(0,30,6)] )
# ax.set_yticks([datetime.datetime(1+i//12,1+i%12,1) for i in range(0,30,6)])

ax.grid()
cbar2 = plt.colorbar(cs, ax = ax2)
# cbar2.set_label(r'Salinity Anomaly (psu)', rotation=270, labelpad=20, size = 12)

# ax.set_ylabel("Months")
# ax.set_xlabel("Longitude (°)")




#Ross
import datetime
hov_time_datetime2 = range(0,36)


colors = ["k", "r", "b"]
alpha = [1,1,1]
endmonth = [36,36,36,48,48]
reg = (lon_along_contour>-200)&(lon_along_contour<-160)
ax = ax3
for a,i in enumerate([0,1,2]):
    ax.plot(hov_time_datetime2,salt_terranova[a][:endmonth[a]], color = colors[a], alpha = alpha[a])
ax.grid()
ax.plot(hov_time_datetime2,salinity_terranova_bench_mean_36, color = "grey", alpha = 0.8)
ax.fill_between(hov_time_datetime2,salinity_terranova_bench_mean_36 - salinity_terranova_bench_std_36,salinity_terranova_bench_mean_36 + salinity_terranova_bench_std_36 , color = "grey", alpha = 0.2)
ax.set_xticks(range(0,42,6))
ax.set_xlim(0,35)

# ax.set_ylabel("Salinity (psu)")
ax3.set_xticklabels([])
ax = ax4
region = "Ross"
reg_trans = [vol_transp_var.where((lon_along_contour>-200)&(lon_along_contour<-160),drop=True) for vol_transp_var in vol_transp]
for a,i in enumerate([0,1,2]):
    reg_trans_y = reg_trans[i].sel(isopycnal_bins = slice(32.56,None)).sum("isopycnal_bins").sum('contour_index')/1e6
    ax.plot(hov_time_datetime2,reg_trans_y[:endmonth[a]], color = colors[a], alpha = alpha[a])
    
ax.plot(hov_time_datetime2,vol_transp_bench_ross_mean_36, color = "grey", alpha = 0.8)
ax.fill_between(hov_time_datetime2,vol_transp_bench_ross_mean_36 - vol_transp_bench_ross_std_36,vol_transp_bench_ross_mean_36 + vol_transp_bench_ross_std_36 , color = "grey", alpha = 0.2)
# ax.plot(hov_time_datetime,vol_transp_bench_ross[:len(hov_time_datetime)], color = "grey", alpha = 0.8)

# ax.set_ylabel("Transport (Sv)")

# ax.set_xlabel("Months")
ax.grid()
ax.set_xticks(range(0,42,6))
ax.set_xlim(0,35)
ax4.tick_params(labelbottom=True)


# pos2 = ax2.get_position()

# # Move ax4 closer to ax3
# new_left = pos2.x0 + 0.02  # Adjust this value to control spacing
# ax2.set_position([new_left, pos2.y0, pos2.width, pos2.height])


# plt.ylabel("cross 1000m DSW transport")
plt.tight_layout()
# plt.subplots_adjust(hspace=0.15)  # Reduce vertical spacing between subplots

# %%
maxage = float(da_agebottom.sel(scenario = "Neutral").max())

# %%
da_swmt_shelf = xr.open_dataarray("/g/data/oz91/ma3822/ZW3/data/swmt_sig0_yr12.nc").isel(isopycnal_bins = 15)


import matplotlib.gridspec as gridspec

f = plt.figure(figsize = (12,8))

# Create a gridspec with custom spacing
gs = gridspec.GridSpec(3, 2, 
                       height_ratios=[1, 1, 1],  # Equal heights for all rows
                       hspace=0.3)  # Overall vertical spacing

# Create a gridspec with custom spacing
gs2 = gridspec.GridSpec(3, 3, 
                       height_ratios=[1, 1, 1],  # Equal heights for all rows
                       hspace=0.3)  # Overall vertical spacing

# Create subplots using gridspec
ax1 = plt.subplot(gs2[0, 0])
ax2 = plt.subplot(gs[0, 1])

# For the bottom two plots, create a sub-gridspec with tighter spacing
gs_bottom = gridspec.GridSpecFromSubplotSpec(2, 1, gs[1:, :], 
                                            hspace=0.1)  # Tight spacing between bottom plots

ax4 = plt.subplot(gs_bottom[1])
ax3 = plt.subplot(gs_bottom[0], sharex=ax4)


ax = ax1
ax.contour(shelf_mask.xt_ocean, shelf_mask.yt_ocean, shelf_mask, [0, 1],
           colors='k', alpha =0.8)

norm = col.Normalize(vmin=0, vmax=2.5)


cs = ax.pcolormesh(da_agebottom.xt_ocean, da_agebottom.yt_ocean, da_agebottom.sel(scenario = "PC1Plus")/maxage - da_agebottom.sel(scenario = "Neutral")/maxage,
                       cmap=cm.cm.balance, vmin=-0.1, vmax=0.1)

swmt_loc = da_swmt_shelf
swmt_loc = swmt_loc.where(swmt_loc>0)

plot_swmt = ax.pcolormesh(da_swmt_shelf.xt_ocean, da_swmt_shelf.yt_ocean, swmt_loc.sel(scenario = "PC1Plus"),
                           cmap=cm.cm.matter, vmin = 0, vmax = 2.5*1e-5)
land = xr.where(np.isnan(bathy.rename('land')), 1, np.nan)
land.plot(ax = ax,add_colorbar =False, cmap = "Greys")
lim_regional("Ross", ax,bathy)
ax.set_xlabel(None)
ax.set_ylabel(None)
# ax.set_ylabel("Latitude (°)")
# ax.set_xlabel("Longitude (°)")

# cbar1 = plt.colorbar(cs, ax = ax1)
# cbar1.set_label(r'Age Bottom Anomaly (years)', rotation=270, labelpad=20, size = 12)
# cbar1.set_label(r'Age Bottom Anomaly (years)',  size = 12)

# pos1 = ax1.get_position()
# Create small axes for SWMT colorbar (positioned in upper left of ax1)
# cbar_ax_swmt = f.add_axes([pos1.x0 + 0.22, pos1.y1 - 0.14, 0.05, 0.01])  # [left, bottom, width, height]
# cbar_swmt = plt.colorbar(plot_swmt, cax=cbar_ax_swmt)
# cbar_swmt = plt.colorbar(plot_swmt, ax = ax1)
# cbar_swmt.set_label(r'Surface Transformation (m/s)',size = 12)

ax = ax2
hov = southernmost_saltanom_PC1plus.sel(time = slice("2180-01-01", "2182-01-01"))
hov_time_datetime = [datetime.datetime(1,1,2) + datetime.timedelta(days = i) for i in range(len(hov.time))]

cs = ax.pcolormesh(hov.xt_ocean_sub01,hov_time_datetime, hov, cmap = cm.cm.balance, vmin = -0.3,vmax = 0.3)
# ax.colorbar()
ax.set_yticks([datetime.datetime(1+i//12,1+i%12,1) for i in range(0,30,6)], labels =[r'${}$'.format(i) for i in range(0,30,6)] )
# ax.set_yticks([datetime.datetime(1+i//12,1+i%12,1) for i in range(0,30,6)])

ax.grid()
cbar2 = plt.colorbar(cs, ax = ax2)
# cbar2.set_label(r'Salinity Anomaly (psu)', rotation=270, labelpad=20, size = 12)

# ax.set_ylabel("Months")
# ax.set_xlabel("Longitude (°)")




#Ross
import datetime
hov_time_datetime2 = range(0,36)


colors = ["k", "r", "b"]
alpha = [1,1,1]
endmonth = [36,36,36,48,48]
reg = (lon_along_contour>-200)&(lon_along_contour<-160)
ax = ax3
for a,i in enumerate([0,1,2]):
    ax.plot(hov_time_datetime2,salt_terranova[a][:endmonth[a]], color = colors[a], alpha = alpha[a])
ax.grid()
ax.plot(hov_time_datetime2,salinity_terranova_bench_mean_36, color = "grey", alpha = 0.8)
ax.fill_between(hov_time_datetime2,salinity_terranova_bench_mean_36 - salinity_terranova_bench_std_36,salinity_terranova_bench_mean_36 + salinity_terranova_bench_std_36 , color = "grey", alpha = 0.2)
ax.set_xticks(range(0,42,6))
ax.set_xlim(0,35)

# ax.set_ylabel("Salinity (psu)")
ax3.set_xticklabels([])
ax = ax4
region = "Ross"
reg_trans = [vol_transp_var.where((lon_along_contour>-200)&(lon_along_contour<-160),drop=True) for vol_transp_var in vol_transp]
for a,i in enumerate([0,1,2]):
    reg_trans_y = reg_trans[i].sel(isopycnal_bins = slice(32.56,None)).sum("isopycnal_bins").sum('contour_index')/1e6
    ax.plot(hov_time_datetime2,reg_trans_y[:endmonth[a]], color = colors[a], alpha = alpha[a])
    
ax.plot(hov_time_datetime2,vol_transp_bench_ross_mean_36, color = "grey", alpha = 0.8)
ax.fill_between(hov_time_datetime2,vol_transp_bench_ross_mean_36 - vol_transp_bench_ross_std_36,vol_transp_bench_ross_mean_36 + vol_transp_bench_ross_std_36 , color = "grey", alpha = 0.2)
# ax.plot(hov_time_datetime,vol_transp_bench_ross[:len(hov_time_datetime)], color = "grey", alpha = 0.8)

# ax.set_ylabel("Transport (Sv)")

# ax.set_xlabel("Months")
ax.grid()
ax.set_xticks(range(0,42,6))
ax.set_xlim(0,35)
ax4.tick_params(labelbottom=True)


# pos2 = ax2.get_position()

# # Move ax4 closer to ax3
# new_left = pos2.x0 + 0.02  # Adjust this value to control spacing
# ax2.set_position([new_left, pos2.y0, pos2.width, pos2.height])


# plt.ylabel("cross 1000m DSW transport")
plt.tight_layout()
# plt.subplots_adjust(hspace=0.15)  # Reduce vertical spacing between subplots

# %%
import matplotlib.gridspec as gridspec

f = plt.figure(figsize = (12,8))

# Create a gridspec with custom spacing
gs = gridspec.GridSpec(3, 2, 
                       height_ratios=[1, 1, 1],  # Equal heights for all rows
                       hspace=0.3)  # Overall vertical spacing

# Create a gridspec with custom spacing
gs2 = gridspec.GridSpec(3, 3, 
                       height_ratios=[1, 1, 1],  # Equal heights for all rows
                       hspace=0.3)  # Overall vertical spacing

# Create subplots using gridspec
ax1 = plt.subplot(gs2[0, 0])
ax2 = plt.subplot(gs[0, 1])

# For the bottom two plots, create a sub-gridspec with tighter spacing
gs_bottom = gridspec.GridSpecFromSubplotSpec(2, 1, gs[1:, :], 
                                            hspace=0.1)  # Tight spacing between bottom plots

ax4 = plt.subplot(gs_bottom[1])
ax3 = plt.subplot(gs_bottom[0], sharex=ax4)


ax = ax1
ax.contour(shelf_mask.xt_ocean, shelf_mask.yt_ocean, shelf_mask, [0, 1],
           colors='k', alpha =0.8)

norm = col.Normalize(vmin=0, vmax=2.5)


cs = ax.pcolormesh(da_agebottom.xt_ocean, da_agebottom.yt_ocean, da_agebottom.sel(scenario = "PC1Plus")/maxage - da_agebottom.sel(scenario = "Neutral")/maxage,
                       cmap=cm.cm.balance, vmin=-0.1, vmax=0.1)

swmt_loc = da_swmt_shelf
swmt_loc = swmt_loc.where(swmt_loc>0)

plot_swmt = ax.pcolormesh(da_swmt_shelf.xt_ocean, da_swmt_shelf.yt_ocean, swmt_loc.sel(scenario = "PC1Plus"),
                           cmap=cm.cm.matter, vmin = 0, vmax = 2.5*1e-5)
land = xr.where(np.isnan(bathy.rename('land')), 1, np.nan)
land.plot(ax = ax,add_colorbar =False, cmap = "Greys")
lim_regional("Ross", ax,bathy)
ax.set_xlabel(None)
ax.set_ylabel(None)
# ax.set_ylabel("Latitude (°)")
# ax.set_xlabel("Longitude (°)")

cbar1 = plt.colorbar(cs, ax = ax1)
# cbar1.set_label(r'Age Bottom Anomaly (years)', rotation=270, labelpad=20, size = 12)
# cbar1.set_label(r'Age Bottom Anomaly (years)',  size = 12)

# pos1 = ax1.get_position()
# Create small axes for SWMT colorbar (positioned in upper left of ax1)
# cbar_ax_swmt = f.add_axes([pos1.x0 + 0.22, pos1.y1 - 0.14, 0.05, 0.01])  # [left, bottom, width, height]
# cbar_swmt = plt.colorbar(plot_swmt, cax=cbar_ax_swmt)
# cbar_swmt = plt.colorbar(plot_swmt, ax = ax1)
# cbar_swmt.set_label(r'Surface Transformation (m/s)',size = 12)

ax = ax2
hov = southernmost_saltanom_PC1plus.sel(time = slice("2180-01-01", "2182-01-01"))
hov_time_datetime = [datetime.datetime(1,1,2) + datetime.timedelta(days = i) for i in range(len(hov.time))]

cs = ax.pcolormesh(hov.xt_ocean_sub01,hov_time_datetime, hov, cmap = cm.cm.balance, vmin = -0.4,vmax = 0.4)
# ax.colorbar()
ax.set_yticks([datetime.datetime(1+i//12,1+i%12,1) for i in range(0,30,6)], labels =[r'${}$'.format(i) for i in range(0,30,6)] )
# ax.set_yticks([datetime.datetime(1+i//12,1+i%12,1) for i in range(0,30,6)])

ax.grid()
cbar2 = plt.colorbar(cs, ax = ax2)
# cbar2.set_label(r'Salinity Anomaly (psu)', rotation=270, labelpad=20, size = 12)

# ax.set_ylabel("Months")
# ax.set_xlabel("Longitude (°)")




#Ross
import datetime
hov_time_datetime2 = range(0,36)


colors = ["k", "r", "b"]
alpha = [1,1,1]
endmonth = [36,36,36,48,48]
reg = (lon_along_contour>-200)&(lon_along_contour<-160)
ax = ax3
for a,i in enumerate([0,1,2]):
    ax.plot(hov_time_datetime2,salt_terranova[a][:endmonth[a]], color = colors[a], alpha = alpha[a])
ax.grid()
ax.plot(hov_time_datetime2,salinity_terranova_bench_mean_36, color = "grey", alpha = 0.8)
ax.fill_between(hov_time_datetime2,salinity_terranova_bench_mean_36 - salinity_terranova_bench_std_36,salinity_terranova_bench_mean_36 + salinity_terranova_bench_std_36 , color = "grey", alpha = 0.2)
ax.set_xticks(range(0,42,6))
ax.set_xlim(0,35)

# ax.set_ylabel("Salinity (psu)")
ax3.set_xticklabels([])
ax = ax4
region = "Ross"
reg_trans = [vol_transp_var.where((lon_along_contour>-200)&(lon_along_contour<-160),drop=True) for vol_transp_var in vol_transp]
for a,i in enumerate([0,1,2]):
    reg_trans_y = reg_trans[i].sel(isopycnal_bins = slice(32.56,None)).sum("isopycnal_bins").sum('contour_index')/1e6
    ax.plot(hov_time_datetime2,reg_trans_y[:endmonth[a]], color = colors[a], alpha = alpha[a])
    
ax.plot(hov_time_datetime2,vol_transp_bench_ross_mean_36, color = "grey", alpha = 0.8)
ax.fill_between(hov_time_datetime2,vol_transp_bench_ross_mean_36 - vol_transp_bench_ross_std_36,vol_transp_bench_ross_mean_36 + vol_transp_bench_ross_std_36 , color = "grey", alpha = 0.2)
# ax.plot(hov_time_datetime,vol_transp_bench_ross[:len(hov_time_datetime)], color = "grey", alpha = 0.8)

# ax.set_ylabel("Transport (Sv)")

# ax.set_xlabel("Months")
ax.grid()
ax.set_xticks(range(0,42,6))
ax.set_xlim(0,35)
ax4.tick_params(labelbottom=True)


# pos2 = ax2.get_position()

# # Move ax4 closer to ax3
# new_left = pos2.x0 + 0.02  # Adjust this value to control spacing
# ax2.set_position([new_left, pos2.y0, pos2.width, pos2.height])


# plt.ylabel("cross 1000m DSW transport")
plt.tight_layout()
# plt.subplots_adjust(hspace=0.15)  # Reduce vertical spacing between subplots

# %%
hov.plot()

# %%
import cmocean as cm
import datetime
hov = southernmost_saltanom_PC1plus.sel(time = slice("2180-01-01", "2182-01-01"))

hov_time_datetime = [datetime.datetime(1,1,2) + datetime.timedelta(days = i) for i in range(len(hov.time))]

plt.figure(figsize = (4,4))
plt.pcolormesh(southernmost_saltanom_PC1plus.xt_ocean_sub01,hov_time_datetime, hov, cmap = cm.cm.balance, vmin = -0.4,vmax = 0.4)
plt.colorbar()
plt.yticks([datetime.datetime(1+i//12,1+i%12,1) for i in range(0,30,6)], labels =range(0,30,6) )
plt.grid()

# %%
vol_transp_bench_weddell = vol_transp_bench.where((lon_along_contour>-60)&(lon_along_contour<-0),drop=True).sel(isopycnal_bins = slice(32.56,None)).sum("isopycnal_bins").sum('contour_index')/1e6
vol_transp_bench_weddell_mean = vol_transp_bench_weddell.groupby('time.month').mean().to_numpy()
vol_transp_bench_weddell_std = vol_transp_bench_weddell.groupby('time.month').std().to_numpy()
vol_transp_bench_weddell_mean_48 = np.array(vol_transp_bench_weddell_mean.tolist()*4)
vol_transp_bench_weddell_std_48 = np.array(vol_transp_bench_weddell_std.tolist()*4)

# %%
hov_time_datetime
# Out:
# [datetime.datetime(1, 1, 2, 0, 0),
#  datetime.datetime(1, 1, 3, 0, 0),
#  datetime.datetime(1, 1, 4, 0, 0),
#  datetime.datetime(1, 1, 5, 0, 0),
#  datetime.datetime(1, 1, 6, 0, 0),
#  datetime.datetime(1, 1, 7, 0, 0),
#  datetime.datetime(1, 1, 8, 0, 0),
#  datetime.datetime(1, 1, 9, 0, 0),
#  datetime.datetime(1, 1, 10, 0, 0),
#  datetime.datetime(1, 1, 11, 0, 0),
#  datetime.datetime(1, 1, 12, 0, 0),
#  datetime.datetime(1, 1, 13, 0, 0),
#  datetime.datetime(1, 1, 14, 0, 0),
#  datetime.datetime(1, 1, 15, 0, 0),
#  datetime.datetime(1, 1, 16, 0, 0),
#  datetime.datetime(1, 1, 17, 0, 0),
#  datetime.datetime(1, 1, 18, 0, 0),
#  datetime.datetime(1, 1, 19, 0, 0),
#  datetime.datetime(1, 1, 20, 0, 0),
#  datetime.datetime(1, 1, 21, 0, 0),
#  datetime.datetime(1, 1, 22, 0, 0),
#  datetime.datetime(1, 1, 23, 0, 0),
#  datetime.datetime(1, 1, 24, 0, 0),
#  datetime.datetime(1, 1, 25, 0, 0),
#  datetime.datetime(1, 1, 26, 0, 0),
#  datetime.datetime(1, 1, 27, 0, 0),
#  datetime.datetime(1, 1, 28, 0, 0),
#  datetime.datetime(1, 1, 29, 0, 0),
#  datetime.datetime(1, 1, 30, 0, 0),
#  datetime.datetime(1, 1, 31, 0, 0),
#  datetime.datetime(1, 2, 1, 0, 0),
#  datetime.datetime(1, 2, 2, 0, 0),
#  datetime.datetime(1, 2, 3, 0, 0),
#  datetime.datetime(1, 2, 4, 0, 0),
#  datetime.datetime(1, 2, 5, 0, 0),
#  datetime.datetime(1, 2, 6, 0, 0),
#  datetime.datetime(1, 2, 7, 0, 0),
#  datetime.datetime(1, 2, 8, 0, 0),
#  datetime.datetime(1, 2, 9, 0, 0),
#  datetime.datetime(1, 2, 10, 0, 0),
#  datetime.datetime(1, 2, 11, 0, 0),
#  datetime.datetime(1, 2, 12, 0, 0),
#  datetime.datetime(1, 2, 13, 0, 0),
#  datetime.datetime(1, 2, 14, 0, 0),
#  datetime.datetime(1, 2, 15, 0, 0),
#  datetime.datetime(1, 2, 16, 0, 0),
#  datetime.datetime(1, 2, 17, 0, 0),
#  datetime.datetime(1, 2, 18, 0, 0),
#  datetime.datetime(1, 2, 19, 0, 0),
#  datetime.datetime(1, 2, 20, 0, 0),
#  datetime.datetime(1, 2, 21, 0, 0),
#  datetime.datetime(1, 2, 22, 0, 0),
#  datetime.datetime(1, 2, 23, 0, 0),
#  datetime.datetime(1, 2, 24, 0, 0),
#  datetime.datetime(1, 2, 25, 0, 0),
#  datetime.datetime(1, 2, 26, 0, 0),
#  datetime.datetime(1, 2, 27, 0, 0),
#  datetime.datetime(1, 2, 28, 0, 0),
#  datetime.datetime(1, 3, 1, 0, 0),
#  datetime.datetime(1, 3, 2, 0, 0),
#  datetime.datetime(1, 3, 3, 0, 0),
#  datetime.datetime(1, 3, 4, 0, 0),
#  datetime.datetime(1, 3, 5, 0, 0),
#  datetime.datetime(1, 3, 6, 0, 0),
#  datetime.datetime(1, 3, 7, 0, 0),
#  datetime.datetime(1, 3, 8, 0, 0),
#  datetime.datetime(1, 3, 9, 0, 0),
#  datetime.datetime(1, 3, 10, 0, 0),
#  datetime.datetime(1, 3, 11, 0, 0),
#  datetime.datetime(1, 3, 12, 0, 0),
#  datetime.datetime(1, 3, 13, 0, 0),
#  datetime.datetime(1, 3, 14, 0, 0),
#  datetime.datetime(1, 3, 15, 0, 0),
#  datetime.datetime(1, 3, 16, 0, 0),
#  datetime.datetime(1, 3, 17, 0, 0),
#  datetime.datetime(1, 3, 18, 0, 0),
#  datetime.datetime(1, 3, 19, 0, 0),
#  datetime.datetime(1, 3, 20, 0, 0),
#  datetime.datetime(1, 3, 21, 0, 0),
#  datetime.datetime(1, 3, 22, 0, 0),
#  datetime.datetime(1, 3, 23, 0, 0),
#  datetime.datetime(1, 3, 24, 0, 0),
#  datetime.datetime(1, 3, 25, 0, 0),
#  datetime.datetime(1, 3, 26, 0, 0),
#  datetime.datetime(1, 3, 27, 0, 0),
#  datetime.datetime(1, 3, 28, 0, 0),
#  datetime.datetime(1, 3, 29, 0, 0),
#  datetime.datetime(1, 3, 30, 0, 0),
#  datetime.datetime(1, 3, 31, 0, 0),
#  datetime.datetime(1, 4, 1, 0, 0),
#  datetime.datetime(1, 4, 2, 0, 0),
#  datetime.datetime(1, 4, 3, 0, 0),
#  datetime.datetime(1, 4, 4, 0, 0),
#  datetime.datetime(1, 4, 5, 0, 0),
#  datetime.datetime(1, 4, 6, 0, 0),
#  datetime.datetime(1, 4, 7, 0, 0),
#  datetime.datetime(1, 4, 8, 0, 0),
#  datetime.datetime(1, 4, 9, 0, 0),
#  datetime.datetime(1, 4, 10, 0, 0),
#  datetime.datetime(1, 4, 11, 0, 0),
#  datetime.datetime(1, 4, 12, 0, 0),
#  datetime.datetime(1, 4, 13, 0, 0),
#  datetime.datetime(1, 4, 14, 0, 0),
#  datetime.datetime(1, 4, 15, 0, 0),
#  datetime.datetime(1, 4, 16, 0, 0),
#  datetime.datetime(1, 4, 17, 0, 0),
#  datetime.datetime(1, 4, 18, 0, 0),
#  datetime.datetime(1, 4, 19, 0, 0),
#  datetime.datetime(1, 4, 20, 0, 0),
#  datetime.datetime(1, 4, 21, 0, 0),
#  datetime.datetime(1, 4, 22, 0, 0),
#  datetime.datetime(1, 4, 23, 0, 0),
#  datetime.datetime(1, 4, 24, 0, 0),
#  datetime.datetime(1, 4, 25, 0, 0),
#  datetime.datetime(1, 4, 26, 0, 0),
#  datetime.datetime(1, 4, 27, 0, 0),
#  datetime.datetime(1, 4, 28, 0, 0),
#  datetime.datetime(1, 4, 29, 0, 0),
#  datetime.datetime(1, 4, 30, 0, 0),
#  datetime.datetime(1, 5, 1, 0, 0),
#  datetime.datetime(1, 5, 2, 0, 0),
#  datetime.datetime(1, 5, 3, 0, 0),
#  datetime.datetime(1, 5, 4, 0, 0),
#  datetime.datetime(1, 5, 5, 0, 0),
#  datetime.datetime(1, 5, 6, 0, 0),
#  datetime.datetime(1, 5, 7, 0, 0),
#  datetime.datetime(1, 5, 8, 0, 0),
#  datetime.datetime(1, 5, 9, 0, 0),
#  datetime.datetime(1, 5, 10, 0, 0),
#  datetime.datetime(1, 5, 11, 0, 0),
#  datetime.datetime(1, 5, 12, 0, 0),
#  datetime.datetime(1, 5, 13, 0, 0),
#  datetime.datetime(1, 5, 14, 0, 0),
#  datetime.datetime(1, 5, 15, 0, 0),
#  datetime.datetime(1, 5, 16, 0, 0),
#  datetime.datetime(1, 5, 17, 0, 0),
#  datetime.datetime(1, 5, 18, 0, 0),
#  datetime.datetime(1, 5, 19, 0, 0),
#  datetime.datetime(1, 5, 20, 0, 0),
#  datetime.datetime(1, 5, 21, 0, 0),
#  datetime.datetime(1, 5, 22, 0, 0),
#  datetime.datetime(1, 5, 23, 0, 0),
#  datetime.datetime(1, 5, 24, 0, 0),
#  datetime.datetime(1, 5, 25, 0, 0),
#  datetime.datetime(1, 5, 26, 0, 0),
#  datetime.datetime(1, 5, 27, 0, 0),
#  datetime.datetime(1, 5, 28, 0, 0),
#  datetime.datetime(1, 5, 29, 0, 0),
#  datetime.datetime(1, 5, 30, 0, 0),
#  datetime.datetime(1, 5, 31, 0, 0),
#  datetime.datetime(1, 6, 1, 0, 0),
#  datetime.datetime(1, 6, 2, 0, 0),
#  datetime.datetime(1, 6, 3, 0, 0),
#  datetime.datetime(1, 6, 4, 0, 0),
#  datetime.datetime(1, 6, 5, 0, 0),
#  datetime.datetime(1, 6, 6, 0, 0),
#  datetime.datetime(1, 6, 7, 0, 0),
#  datetime.datetime(1, 6, 8, 0, 0),
#  datetime.datetime(1, 6, 9, 0, 0),
#  datetime.datetime(1, 6, 10, 0, 0),
#  datetime.datetime(1, 6, 11, 0, 0),
#  datetime.datetime(1, 6, 12, 0, 0),
#  datetime.datetime(1, 6, 13, 0, 0),
#  datetime.datetime(1, 6, 14, 0, 0),
#  datetime.datetime(1, 6, 15, 0, 0),
#  datetime.datetime(1, 6, 16, 0, 0),
#  datetime.datetime(1, 6, 17, 0, 0),
#  datetime.datetime(1, 6, 18, 0, 0),
#  datetime.datetime(1, 6, 19, 0, 0),
#  datetime.datetime(1, 6, 20, 0, 0),
#  datetime.datetime(1, 6, 21, 0, 0),
#  datetime.datetime(1, 6, 22, 0, 0),
#  datetime.datetime(1, 6, 23, 0, 0),
#  datetime.datetime(1, 6, 24, 0, 0),
#  datetime.datetime(1, 6, 25, 0, 0),
#  datetime.datetime(1, 6, 26, 0, 0),
#  datetime.datetime(1, 6, 27, 0, 0),
#  datetime.datetime(1, 6, 28, 0, 0),
#  datetime.datetime(1, 6, 29, 0, 0),
#  datetime.datetime(1, 6, 30, 0, 0),
#  datetime.datetime(1, 7, 1, 0, 0),
#  datetime.datetime(1, 7, 2, 0, 0),
#  datetime.datetime(1, 7, 3, 0, 0),
#  datetime.datetime(1, 7, 4, 0, 0),
#  datetime.datetime(1, 7, 5, 0, 0),
#  datetime.datetime(1, 7, 6, 0, 0),
#  datetime.datetime(1, 7, 7, 0, 0),
#  datetime.datetime(1, 7, 8, 0, 0),
#  datetime.datetime(1, 7, 9, 0, 0),
#  datetime.datetime(1, 7, 10, 0, 0),
#  datetime.datetime(1, 7, 11, 0, 0),
#  datetime.datetime(1, 7, 12, 0, 0),
#  datetime.datetime(1, 7, 13, 0, 0),
#  datetime.datetime(1, 7, 14, 0, 0),
#  datetime.datetime(1, 7, 15, 0, 0),
#  datetime.datetime(1, 7, 16, 0, 0),
#  datetime.datetime(1, 7, 17, 0, 0),
#  datetime.datetime(1, 7, 18, 0, 0),
#  datetime.datetime(1, 7, 19, 0, 0),
#  datetime.datetime(1, 7, 20, 0, 0),
#  datetime.datetime(1, 7, 21, 0, 0),
#  datetime.datetime(1, 7, 22, 0, 0),
#  datetime.datetime(1, 7, 23, 0, 0),
#  datetime.datetime(1, 7, 24, 0, 0),
#  datetime.datetime(1, 7, 25, 0, 0),
#  datetime.datetime(1, 7, 26, 0, 0),
#  datetime.datetime(1, 7, 27, 0, 0),
#  datetime.datetime(1, 7, 28, 0, 0),
#  datetime.datetime(1, 7, 29, 0, 0),
#  datetime.datetime(1, 7, 30, 0, 0),
#  datetime.datetime(1, 7, 31, 0, 0),
#  datetime.datetime(1, 8, 1, 0, 0),
#  datetime.datetime(1, 8, 2, 0, 0),
#  datetime.datetime(1, 8, 3, 0, 0),
#  datetime.datetime(1, 8, 4, 0, 0),
#  datetime.datetime(1, 8, 5, 0, 0),
#  datetime.datetime(1, 8, 6, 0, 0),
#  datetime.datetime(1, 8, 7, 0, 0),
#  datetime.datetime(1, 8, 8, 0, 0),
#  datetime.datetime(1, 8, 9, 0, 0),
#  datetime.datetime(1, 8, 10, 0, 0),
#  datetime.datetime(1, 8, 11, 0, 0),
#  datetime.datetime(1, 8, 12, 0, 0),
#  datetime.datetime(1, 8, 13, 0, 0),
#  datetime.datetime(1, 8, 14, 0, 0),
#  datetime.datetime(1, 8, 15, 0, 0),
#  datetime.datetime(1, 8, 16, 0, 0),
#  datetime.datetime(1, 8, 17, 0, 0),
#  datetime.datetime(1, 8, 18, 0, 0),
#  datetime.datetime(1, 8, 19, 0, 0),
#  datetime.datetime(1, 8, 20, 0, 0),
#  datetime.datetime(1, 8, 21, 0, 0),
#  datetime.datetime(1, 8, 22, 0, 0),
#  datetime.datetime(1, 8, 23, 0, 0),
#  datetime.datetime(1, 8, 24, 0, 0),
#  datetime.datetime(1, 8, 25, 0, 0),
#  datetime.datetime(1, 8, 26, 0, 0),
#  datetime.datetime(1, 8, 27, 0, 0),
#  datetime.datetime(1, 8, 28, 0, 0),
#  datetime.datetime(1, 8, 29, 0, 0),
#  datetime.datetime(1, 8, 30, 0, 0),
#  datetime.datetime(1, 8, 31, 0, 0),
#  datetime.datetime(1, 9, 1, 0, 0),
#  datetime.datetime(1, 9, 2, 0, 0),
#  datetime.datetime(1, 9, 3, 0, 0),
#  datetime.datetime(1, 9, 4, 0, 0),
#  datetime.datetime(1, 9, 5, 0, 0),
#  datetime.datetime(1, 9, 6, 0, 0),
#  datetime.datetime(1, 9, 7, 0, 0),
#  datetime.datetime(1, 9, 8, 0, 0),
#  datetime.datetime(1, 9, 9, 0, 0),
#  datetime.datetime(1, 9, 10, 0, 0),
#  datetime.datetime(1, 9, 11, 0, 0),
#  datetime.datetime(1, 9, 12, 0, 0),
#  datetime.datetime(1, 9, 13, 0, 0),
#  datetime.datetime(1, 9, 14, 0, 0),
#  datetime.datetime(1, 9, 15, 0, 0),
#  datetime.datetime(1, 9, 16, 0, 0),
#  datetime.datetime(1, 9, 17, 0, 0),
#  datetime.datetime(1, 9, 18, 0, 0),
#  datetime.datetime(1, 9, 19, 0, 0),
#  datetime.datetime(1, 9, 20, 0, 0),
#  datetime.datetime(1, 9, 21, 0, 0),
#  datetime.datetime(1, 9, 22, 0, 0),
#  datetime.datetime(1, 9, 23, 0, 0),
#  datetime.datetime(1, 9, 24, 0, 0),
#  datetime.datetime(1, 9, 25, 0, 0),
#  datetime.datetime(1, 9, 26, 0, 0),
#  datetime.datetime(1, 9, 27, 0, 0),
#  datetime.datetime(1, 9, 28, 0, 0),
#  datetime.datetime(1, 9, 29, 0, 0),
#  datetime.datetime(1, 9, 30, 0, 0),
#  datetime.datetime(1, 10, 1, 0, 0),
#  datetime.datetime(1, 10, 2, 0, 0),
#  datetime.datetime(1, 10, 3, 0, 0),
#  datetime.datetime(1, 10, 4, 0, 0),
#  datetime.datetime(1, 10, 5, 0, 0),
#  datetime.datetime(1, 10, 6, 0, 0),
#  datetime.datetime(1, 10, 7, 0, 0),
#  datetime.datetime(1, 10, 8, 0, 0),
#  datetime.datetime(1, 10, 9, 0, 0),
#  datetime.datetime(1, 10, 10, 0, 0),
#  datetime.datetime(1, 10, 11, 0, 0),
#  datetime.datetime(1, 10, 12, 0, 0),
#  datetime.datetime(1, 10, 13, 0, 0),
#  datetime.datetime(1, 10, 14, 0, 0),
#  datetime.datetime(1, 10, 15, 0, 0),
#  datetime.datetime(1, 10, 16, 0, 0),
#  datetime.datetime(1, 10, 17, 0, 0),
#  datetime.datetime(1, 10, 18, 0, 0),
#  datetime.datetime(1, 10, 19, 0, 0),
#  datetime.datetime(1, 10, 20, 0, 0),
#  datetime.datetime(1, 10, 21, 0, 0),
#  datetime.datetime(1, 10, 22, 0, 0),
#  datetime.datetime(1, 10, 23, 0, 0),
#  datetime.datetime(1, 10, 24, 0, 0),
#  datetime.datetime(1, 10, 25, 0, 0),
#  datetime.datetime(1, 10, 26, 0, 0),
#  datetime.datetime(1, 10, 27, 0, 0),
#  datetime.datetime(1, 10, 28, 0, 0),
#  datetime.datetime(1, 10, 29, 0, 0),
#  datetime.datetime(1, 10, 30, 0, 0),
#  datetime.datetime(1, 10, 31, 0, 0),
#  datetime.datetime(1, 11, 1, 0, 0),
#  datetime.datetime(1, 11, 2, 0, 0),
#  datetime.datetime(1, 11, 3, 0, 0),
#  datetime.datetime(1, 11, 4, 0, 0),
#  datetime.datetime(1, 11, 5, 0, 0),
#  datetime.datetime(1, 11, 6, 0, 0),
#  datetime.datetime(1, 11, 7, 0, 0),
#  datetime.datetime(1, 11, 8, 0, 0),
#  datetime.datetime(1, 11, 9, 0, 0),
#  datetime.datetime(1, 11, 10, 0, 0),
#  datetime.datetime(1, 11, 11, 0, 0),
#  datetime.datetime(1, 11, 12, 0, 0),
#  datetime.datetime(1, 11, 13, 0, 0),
#  datetime.datetime(1, 11, 14, 0, 0),
#  datetime.datetime(1, 11, 15, 0, 0),
#  datetime.datetime(1, 11, 16, 0, 0),
#  datetime.datetime(1, 11, 17, 0, 0),
#  datetime.datetime(1, 11, 18, 0, 0),
#  datetime.datetime(1, 11, 19, 0, 0),
#  datetime.datetime(1, 11, 20, 0, 0),
#  datetime.datetime(1, 11, 21, 0, 0),
#  datetime.datetime(1, 11, 22, 0, 0),
#  datetime.datetime(1, 11, 23, 0, 0),
#  datetime.datetime(1, 11, 24, 0, 0),
#  datetime.datetime(1, 11, 25, 0, 0),
#  datetime.datetime(1, 11, 26, 0, 0),
#  datetime.datetime(1, 11, 27, 0, 0),
#  datetime.datetime(1, 11, 28, 0, 0),
#  datetime.datetime(1, 11, 29, 0, 0),
#  datetime.datetime(1, 11, 30, 0, 0),
#  datetime.datetime(1, 12, 1, 0, 0),
#  datetime.datetime(1, 12, 2, 0, 0),
#  datetime.datetime(1, 12, 3, 0, 0),
#  datetime.datetime(1, 12, 4, 0, 0),
#  datetime.datetime(1, 12, 5, 0, 0),
#  datetime.datetime(1, 12, 6, 0, 0),
#  datetime.datetime(1, 12, 7, 0, 0),
#  datetime.datetime(1, 12, 8, 0, 0),
#  datetime.datetime(1, 12, 9, 0, 0),
#  datetime.datetime(1, 12, 10, 0, 0),
#  datetime.datetime(1, 12, 11, 0, 0),
#  datetime.datetime(1, 12, 12, 0, 0),
#  datetime.datetime(1, 12, 13, 0, 0),
#  datetime.datetime(1, 12, 14, 0, 0),
#  datetime.datetime(1, 12, 15, 0, 0),
#  datetime.datetime(1, 12, 16, 0, 0),
#  datetime.datetime(1, 12, 17, 0, 0),
#  datetime.datetime(1, 12, 18, 0, 0),
#  datetime.datetime(1, 12, 19, 0, 0),
#  datetime.datetime(1, 12, 20, 0, 0),
#  datetime.datetime(1, 12, 21, 0, 0),
#  datetime.datetime(1, 12, 22, 0, 0),
#  datetime.datetime(1, 12, 23, 0, 0),
#  datetime.datetime(1, 12, 24, 0, 0),
#  datetime.datetime(1, 12, 25, 0, 0),
#  datetime.datetime(1, 12, 26, 0, 0),
#  datetime.datetime(1, 12, 27, 0, 0),
#  datetime.datetime(1, 12, 28, 0, 0),
#  datetime.datetime(1, 12, 29, 0, 0),
#  datetime.datetime(1, 12, 30, 0, 0),
#  datetime.datetime(1, 12, 31, 0, 0),
#  datetime.datetime(2, 1, 1, 0, 0),
#  datetime.datetime(2, 1, 2, 0, 0),
#  datetime.datetime(2, 1, 3, 0, 0),
#  datetime.datetime(2, 1, 4, 0, 0),
#  datetime.datetime(2, 1, 5, 0, 0),
#  datetime.datetime(2, 1, 6, 0, 0),
#  datetime.datetime(2, 1, 7, 0, 0),
#  datetime.datetime(2, 1, 8, 0, 0),
#  datetime.datetime(2, 1, 9, 0, 0),
#  datetime.datetime(2, 1, 10, 0, 0),
#  datetime.datetime(2, 1, 11, 0, 0),
#  datetime.datetime(2, 1, 12, 0, 0),
#  datetime.datetime(2, 1, 13, 0, 0),
#  datetime.datetime(2, 1, 14, 0, 0),
#  datetime.datetime(2, 1, 15, 0, 0),
#  datetime.datetime(2, 1, 16, 0, 0),
#  datetime.datetime(2, 1, 17, 0, 0),
#  datetime.datetime(2, 1, 18, 0, 0),
#  datetime.datetime(2, 1, 19, 0, 0),
#  datetime.datetime(2, 1, 20, 0, 0),
#  datetime.datetime(2, 1, 21, 0, 0),
#  datetime.datetime(2, 1, 22, 0, 0),
#  datetime.datetime(2, 1, 23, 0, 0),
#  datetime.datetime(2, 1, 24, 0, 0),
#  datetime.datetime(2, 1, 25, 0, 0),
#  datetime.datetime(2, 1, 26, 0, 0),
#  datetime.datetime(2, 1, 27, 0, 0),
#  datetime.datetime(2, 1, 28, 0, 0),
#  datetime.datetime(2, 1, 29, 0, 0),
#  datetime.datetime(2, 1, 30, 0, 0),
#  datetime.datetime(2, 1, 31, 0, 0),
#  datetime.datetime(2, 2, 1, 0, 0),
#  datetime.datetime(2, 2, 2, 0, 0),
#  datetime.datetime(2, 2, 3, 0, 0),
#  datetime.datetime(2, 2, 4, 0, 0),
#  datetime.datetime(2, 2, 5, 0, 0),
#  datetime.datetime(2, 2, 6, 0, 0),
#  datetime.datetime(2, 2, 7, 0, 0),
#  datetime.datetime(2, 2, 8, 0, 0),
#  datetime.datetime(2, 2, 9, 0, 0),
#  datetime.datetime(2, 2, 10, 0, 0),
#  datetime.datetime(2, 2, 11, 0, 0),
#  datetime.datetime(2, 2, 12, 0, 0),
#  datetime.datetime(2, 2, 13, 0, 0),
#  datetime.datetime(2, 2, 14, 0, 0),
#  datetime.datetime(2, 2, 15, 0, 0),
#  datetime.datetime(2, 2, 16, 0, 0),
#  datetime.datetime(2, 2, 17, 0, 0),
#  datetime.datetime(2, 2, 18, 0, 0),
#  datetime.datetime(2, 2, 19, 0, 0),
#  datetime.datetime(2, 2, 20, 0, 0),
#  datetime.datetime(2, 2, 21, 0, 0),
#  datetime.datetime(2, 2, 22, 0, 0),
#  datetime.datetime(2, 2, 23, 0, 0),
#  datetime.datetime(2, 2, 24, 0, 0),
#  datetime.datetime(2, 2, 25, 0, 0),
#  datetime.datetime(2, 2, 26, 0, 0),
#  datetime.datetime(2, 2, 27, 0, 0),
#  datetime.datetime(2, 2, 28, 0, 0),
#  datetime.datetime(2, 3, 1, 0, 0),
#  datetime.datetime(2, 3, 2, 0, 0),
#  datetime.datetime(2, 3, 3, 0, 0),
#  datetime.datetime(2, 3, 4, 0, 0),
#  datetime.datetime(2, 3, 5, 0, 0),
#  datetime.datetime(2, 3, 6, 0, 0),
#  datetime.datetime(2, 3, 7, 0, 0),
#  datetime.datetime(2, 3, 8, 0, 0),
#  datetime.datetime(2, 3, 9, 0, 0),
#  datetime.datetime(2, 3, 10, 0, 0),
#  datetime.datetime(2, 3, 11, 0, 0),
#  datetime.datetime(2, 3, 12, 0, 0),
#  datetime.datetime(2, 3, 13, 0, 0),
#  datetime.datetime(2, 3, 14, 0, 0),
#  datetime.datetime(2, 3, 15, 0, 0),
#  datetime.datetime(2, 3, 16, 0, 0),
#  datetime.datetime(2, 3, 17, 0, 0),
#  datetime.datetime(2, 3, 18, 0, 0),
#  datetime.datetime(2, 3, 19, 0, 0),
#  datetime.datetime(2, 3, 20, 0, 0),
#  datetime.datetime(2, 3, 21, 0, 0),
#  datetime.datetime(2, 3, 22, 0, 0),
#  datetime.datetime(2, 3, 23, 0, 0),
#  datetime.datetime(2, 3, 24, 0, 0),
#  datetime.datetime(2, 3, 25, 0, 0),
#  datetime.datetime(2, 3, 26, 0, 0),
#  datetime.datetime(2, 3, 27, 0, 0),
#  datetime.datetime(2, 3, 28, 0, 0),
#  datetime.datetime(2, 3, 29, 0, 0),
#  datetime.datetime(2, 3, 30, 0, 0),
#  datetime.datetime(2, 3, 31, 0, 0),
#  datetime.datetime(2, 4, 1, 0, 0),
#  datetime.datetime(2, 4, 2, 0, 0),
#  datetime.datetime(2, 4, 3, 0, 0),
#  datetime.datetime(2, 4, 4, 0, 0),
#  datetime.datetime(2, 4, 5, 0, 0),
#  datetime.datetime(2, 4, 6, 0, 0),
#  datetime.datetime(2, 4, 7, 0, 0),
#  datetime.datetime(2, 4, 8, 0, 0),
#  datetime.datetime(2, 4, 9, 0, 0),
#  datetime.datetime(2, 4, 10, 0, 0),
#  datetime.datetime(2, 4, 11, 0, 0),
#  datetime.datetime(2, 4, 12, 0, 0),
#  datetime.datetime(2, 4, 13, 0, 0),
#  datetime.datetime(2, 4, 14, 0, 0),
#  datetime.datetime(2, 4, 15, 0, 0),
#  datetime.datetime(2, 4, 16, 0, 0),
#  datetime.datetime(2, 4, 17, 0, 0),
#  datetime.datetime(2, 4, 18, 0, 0),
#  datetime.datetime(2, 4, 19, 0, 0),
#  datetime.datetime(2, 4, 20, 0, 0),
#  datetime.datetime(2, 4, 21, 0, 0),
#  datetime.datetime(2, 4, 22, 0, 0),
#  datetime.datetime(2, 4, 23, 0, 0),
#  datetime.datetime(2, 4, 24, 0, 0),
#  datetime.datetime(2, 4, 25, 0, 0),
#  datetime.datetime(2, 4, 26, 0, 0),
#  datetime.datetime(2, 4, 27, 0, 0),
#  datetime.datetime(2, 4, 28, 0, 0),
#  datetime.datetime(2, 4, 29, 0, 0),
#  datetime.datetime(2, 4, 30, 0, 0),
#  datetime.datetime(2, 5, 1, 0, 0),
#  datetime.datetime(2, 5, 2, 0, 0),
#  datetime.datetime(2, 5, 3, 0, 0),
#  datetime.datetime(2, 5, 4, 0, 0),
#  datetime.datetime(2, 5, 5, 0, 0),
#  datetime.datetime(2, 5, 6, 0, 0),
#  datetime.datetime(2, 5, 7, 0, 0),
#  datetime.datetime(2, 5, 8, 0, 0),
#  datetime.datetime(2, 5, 9, 0, 0),
#  datetime.datetime(2, 5, 10, 0, 0),
#  datetime.datetime(2, 5, 11, 0, 0),
#  datetime.datetime(2, 5, 12, 0, 0),
#  datetime.datetime(2, 5, 13, 0, 0),
#  datetime.datetime(2, 5, 14, 0, 0),
#  datetime.datetime(2, 5, 15, 0, 0),
#  datetime.datetime(2, 5, 16, 0, 0),
#  datetime.datetime(2, 5, 17, 0, 0),
#  datetime.datetime(2, 5, 18, 0, 0),
#  datetime.datetime(2, 5, 19, 0, 0),
#  datetime.datetime(2, 5, 20, 0, 0),
#  datetime.datetime(2, 5, 21, 0, 0),
#  datetime.datetime(2, 5, 22, 0, 0),
#  datetime.datetime(2, 5, 23, 0, 0),
#  datetime.datetime(2, 5, 24, 0, 0),
#  datetime.datetime(2, 5, 25, 0, 0),
#  datetime.datetime(2, 5, 26, 0, 0),
#  datetime.datetime(2, 5, 27, 0, 0),
#  datetime.datetime(2, 5, 28, 0, 0),
#  datetime.datetime(2, 5, 29, 0, 0),
#  datetime.datetime(2, 5, 30, 0, 0),
#  datetime.datetime(2, 5, 31, 0, 0),
#  datetime.datetime(2, 6, 1, 0, 0),
#  datetime.datetime(2, 6, 2, 0, 0),
#  datetime.datetime(2, 6, 3, 0, 0),
#  datetime.datetime(2, 6, 4, 0, 0),
#  datetime.datetime(2, 6, 5, 0, 0),
#  datetime.datetime(2, 6, 6, 0, 0),
#  datetime.datetime(2, 6, 7, 0, 0),
#  datetime.datetime(2, 6, 8, 0, 0),
#  datetime.datetime(2, 6, 9, 0, 0),
#  datetime.datetime(2, 6, 10, 0, 0),
#  datetime.datetime(2, 6, 11, 0, 0),
#  datetime.datetime(2, 6, 12, 0, 0),
#  datetime.datetime(2, 6, 13, 0, 0),
#  datetime.datetime(2, 6, 14, 0, 0),
#  datetime.datetime(2, 6, 15, 0, 0),
#  datetime.datetime(2, 6, 16, 0, 0),
#  datetime.datetime(2, 6, 17, 0, 0),
#  datetime.datetime(2, 6, 18, 0, 0),
#  datetime.datetime(2, 6, 19, 0, 0),
#  datetime.datetime(2, 6, 20, 0, 0),
#  datetime.datetime(2, 6, 21, 0, 0),
#  datetime.datetime(2, 6, 22, 0, 0),
#  datetime.datetime(2, 6, 23, 0, 0),
#  datetime.datetime(2, 6, 24, 0, 0),
#  datetime.datetime(2, 6, 25, 0, 0),
#  datetime.datetime(2, 6, 26, 0, 0),
#  datetime.datetime(2, 6, 27, 0, 0),
#  datetime.datetime(2, 6, 28, 0, 0),
#  datetime.datetime(2, 6, 29, 0, 0),
#  datetime.datetime(2, 6, 30, 0, 0),
#  datetime.datetime(2, 7, 1, 0, 0),
#  datetime.datetime(2, 7, 2, 0, 0),
#  datetime.datetime(2, 7, 3, 0, 0),
#  datetime.datetime(2, 7, 4, 0, 0),
#  datetime.datetime(2, 7, 5, 0, 0),
#  datetime.datetime(2, 7, 6, 0, 0),
#  datetime.datetime(2, 7, 7, 0, 0),
#  datetime.datetime(2, 7, 8, 0, 0),
#  datetime.datetime(2, 7, 9, 0, 0),
#  datetime.datetime(2, 7, 10, 0, 0),
#  datetime.datetime(2, 7, 11, 0, 0),
#  datetime.datetime(2, 7, 12, 0, 0),
#  datetime.datetime(2, 7, 13, 0, 0),
#  datetime.datetime(2, 7, 14, 0, 0),
#  datetime.datetime(2, 7, 15, 0, 0),
#  datetime.datetime(2, 7, 16, 0, 0),
#  datetime.datetime(2, 7, 17, 0, 0),
#  datetime.datetime(2, 7, 18, 0, 0),
#  datetime.datetime(2, 7, 19, 0, 0),
#  datetime.datetime(2, 7, 20, 0, 0),
#  datetime.datetime(2, 7, 21, 0, 0),
#  datetime.datetime(2, 7, 22, 0, 0),
#  datetime.datetime(2, 7, 23, 0, 0),
#  datetime.datetime(2, 7, 24, 0, 0),
#  datetime.datetime(2, 7, 25, 0, 0),
#  datetime.datetime(2, 7, 26, 0, 0),
#  datetime.datetime(2, 7, 27, 0, 0),
#  datetime.datetime(2, 7, 28, 0, 0),
#  datetime.datetime(2, 7, 29, 0, 0),
#  datetime.datetime(2, 7, 30, 0, 0),
#  datetime.datetime(2, 7, 31, 0, 0),
#  datetime.datetime(2, 8, 1, 0, 0),
#  datetime.datetime(2, 8, 2, 0, 0),
#  datetime.datetime(2, 8, 3, 0, 0),
#  datetime.datetime(2, 8, 4, 0, 0),
#  datetime.datetime(2, 8, 5, 0, 0),
#  datetime.datetime(2, 8, 6, 0, 0),
#  datetime.datetime(2, 8, 7, 0, 0),
#  datetime.datetime(2, 8, 8, 0, 0),
#  datetime.datetime(2, 8, 9, 0, 0),
#  datetime.datetime(2, 8, 10, 0, 0),
#  datetime.datetime(2, 8, 11, 0, 0),
#  datetime.datetime(2, 8, 12, 0, 0),
#  datetime.datetime(2, 8, 13, 0, 0),
#  datetime.datetime(2, 8, 14, 0, 0),
#  datetime.datetime(2, 8, 15, 0, 0),
#  datetime.datetime(2, 8, 16, 0, 0),
#  datetime.datetime(2, 8, 17, 0, 0),
#  datetime.datetime(2, 8, 18, 0, 0),
#  datetime.datetime(2, 8, 19, 0, 0),
#  datetime.datetime(2, 8, 20, 0, 0),
#  datetime.datetime(2, 8, 21, 0, 0),
#  datetime.datetime(2, 8, 22, 0, 0),
#  datetime.datetime(2, 8, 23, 0, 0),
#  datetime.datetime(2, 8, 24, 0, 0),
#  datetime.datetime(2, 8, 25, 0, 0),
#  datetime.datetime(2, 8, 26, 0, 0),
#  datetime.datetime(2, 8, 27, 0, 0),
#  datetime.datetime(2, 8, 28, 0, 0),
#  datetime.datetime(2, 8, 29, 0, 0),
#  datetime.datetime(2, 8, 30, 0, 0),
#  datetime.datetime(2, 8, 31, 0, 0),
#  datetime.datetime(2, 9, 1, 0, 0),
#  datetime.datetime(2, 9, 2, 0, 0),
#  datetime.datetime(2, 9, 3, 0, 0),
#  datetime.datetime(2, 9, 4, 0, 0),
#  datetime.datetime(2, 9, 5, 0, 0),
#  datetime.datetime(2, 9, 6, 0, 0),
#  datetime.datetime(2, 9, 7, 0, 0),
#  datetime.datetime(2, 9, 8, 0, 0),
#  datetime.datetime(2, 9, 9, 0, 0),
#  datetime.datetime(2, 9, 10, 0, 0),
#  datetime.datetime(2, 9, 11, 0, 0),
#  datetime.datetime(2, 9, 12, 0, 0),
#  datetime.datetime(2, 9, 13, 0, 0),
#  datetime.datetime(2, 9, 14, 0, 0),
#  datetime.datetime(2, 9, 15, 0, 0),
#  datetime.datetime(2, 9, 16, 0, 0),
#  datetime.datetime(2, 9, 17, 0, 0),
#  datetime.datetime(2, 9, 18, 0, 0),
#  datetime.datetime(2, 9, 19, 0, 0),
#  datetime.datetime(2, 9, 20, 0, 0),
#  datetime.datetime(2, 9, 21, 0, 0),
#  datetime.datetime(2, 9, 22, 0, 0),
#  datetime.datetime(2, 9, 23, 0, 0),
#  datetime.datetime(2, 9, 24, 0, 0),
#  datetime.datetime(2, 9, 25, 0, 0),
#  datetime.datetime(2, 9, 26, 0, 0),
#  datetime.datetime(2, 9, 27, 0, 0),
#  datetime.datetime(2, 9, 28, 0, 0),
#  datetime.datetime(2, 9, 29, 0, 0),
#  datetime.datetime(2, 9, 30, 0, 0),
#  datetime.datetime(2, 10, 1, 0, 0),
#  datetime.datetime(2, 10, 2, 0, 0),
#  datetime.datetime(2, 10, 3, 0, 0),
#  datetime.datetime(2, 10, 4, 0, 0),
#  datetime.datetime(2, 10, 5, 0, 0),
#  datetime.datetime(2, 10, 6, 0, 0),
#  datetime.datetime(2, 10, 7, 0, 0),
#  datetime.datetime(2, 10, 8, 0, 0),
#  datetime.datetime(2, 10, 9, 0, 0),
#  datetime.datetime(2, 10, 10, 0, 0),
#  datetime.datetime(2, 10, 11, 0, 0),
#  datetime.datetime(2, 10, 12, 0, 0),
#  datetime.datetime(2, 10, 13, 0, 0),
#  datetime.datetime(2, 10, 14, 0, 0),
#  datetime.datetime(2, 10, 15, 0, 0),
#  datetime.datetime(2, 10, 16, 0, 0),
#  datetime.datetime(2, 10, 17, 0, 0),
#  datetime.datetime(2, 10, 18, 0, 0),
#  datetime.datetime(2, 10, 19, 0, 0),
#  datetime.datetime(2, 10, 20, 0, 0),
#  datetime.datetime(2, 10, 21, 0, 0),
#  datetime.datetime(2, 10, 22, 0, 0),
#  datetime.datetime(2, 10, 23, 0, 0),
#  datetime.datetime(2, 10, 24, 0, 0),
#  datetime.datetime(2, 10, 25, 0, 0),
#  datetime.datetime(2, 10, 26, 0, 0),
#  datetime.datetime(2, 10, 27, 0, 0),
#  datetime.datetime(2, 10, 28, 0, 0),
#  datetime.datetime(2, 10, 29, 0, 0),
#  datetime.datetime(2, 10, 30, 0, 0),
#  datetime.datetime(2, 10, 31, 0, 0),
#  datetime.datetime(2, 11, 1, 0, 0),
#  datetime.datetime(2, 11, 2, 0, 0),
#  datetime.datetime(2, 11, 3, 0, 0),
#  datetime.datetime(2, 11, 4, 0, 0),
#  datetime.datetime(2, 11, 5, 0, 0),
#  datetime.datetime(2, 11, 6, 0, 0),
#  datetime.datetime(2, 11, 7, 0, 0),
#  datetime.datetime(2, 11, 8, 0, 0),
#  datetime.datetime(2, 11, 9, 0, 0),
#  datetime.datetime(2, 11, 10, 0, 0),
#  datetime.datetime(2, 11, 11, 0, 0),
#  datetime.datetime(2, 11, 12, 0, 0),
#  datetime.datetime(2, 11, 13, 0, 0),
#  datetime.datetime(2, 11, 14, 0, 0),
#  datetime.datetime(2, 11, 15, 0, 0),
#  datetime.datetime(2, 11, 16, 0, 0),
#  datetime.datetime(2, 11, 17, 0, 0),
#  datetime.datetime(2, 11, 18, 0, 0),
#  datetime.datetime(2, 11, 19, 0, 0),
#  datetime.datetime(2, 11, 20, 0, 0),
#  datetime.datetime(2, 11, 21, 0, 0),
#  datetime.datetime(2, 11, 22, 0, 0),
#  datetime.datetime(2, 11, 23, 0, 0),
#  datetime.datetime(2, 11, 24, 0, 0),
#  datetime.datetime(2, 11, 25, 0, 0),
#  datetime.datetime(2, 11, 26, 0, 0),
#  datetime.datetime(2, 11, 27, 0, 0),
#  datetime.datetime(2, 11, 28, 0, 0),
#  datetime.datetime(2, 11, 29, 0, 0),
#  datetime.datetime(2, 11, 30, 0, 0),
#  datetime.datetime(2, 12, 1, 0, 0),
#  datetime.datetime(2, 12, 2, 0, 0),
#  datetime.datetime(2, 12, 3, 0, 0),
#  datetime.datetime(2, 12, 4, 0, 0),
#  datetime.datetime(2, 12, 5, 0, 0),
#  datetime.datetime(2, 12, 6, 0, 0),
#  datetime.datetime(2, 12, 7, 0, 0),
#  datetime.datetime(2, 12, 8, 0, 0),
#  datetime.datetime(2, 12, 9, 0, 0),
#  datetime.datetime(2, 12, 10, 0, 0),
#  datetime.datetime(2, 12, 11, 0, 0),
#  datetime.datetime(2, 12, 12, 0, 0),
#  datetime.datetime(2, 12, 13, 0, 0),
#  datetime.datetime(2, 12, 14, 0, 0),
#  datetime.datetime(2, 12, 15, 0, 0),
#  datetime.datetime(2, 12, 16, 0, 0),
#  datetime.datetime(2, 12, 17, 0, 0),
#  datetime.datetime(2, 12, 18, 0, 0),
#  datetime.datetime(2, 12, 19, 0, 0),
#  datetime.datetime(2, 12, 20, 0, 0),
#  datetime.datetime(2, 12, 21, 0, 0),
#  datetime.datetime(2, 12, 22, 0, 0),
#  datetime.datetime(2, 12, 23, 0, 0),
#  datetime.datetime(2, 12, 24, 0, 0),
#  datetime.datetime(2, 12, 25, 0, 0),
#  datetime.datetime(2, 12, 26, 0, 0),
#  datetime.datetime(2, 12, 27, 0, 0),
#  datetime.datetime(2, 12, 28, 0, 0),
#  datetime.datetime(2, 12, 29, 0, 0),
#  datetime.datetime(2, 12, 30, 0, 0),
#  datetime.datetime(2, 12, 31, 0, 0),
#  datetime.datetime(3, 1, 1, 0, 0),
#  datetime.datetime(3, 1, 2, 0, 0)]

# %%
#Ross
import datetime
hov_time_datetime = range(0,48)


colors = ["k", "r", "b"]
alpha = [1,1,1]
endmonth = [48,36,36,48,48]
reg = (lon_along_contour>-200)&(lon_along_contour<-160)
f, ax = plt.subplots(1,1,figsize = (12,2), sharex = True)

# ax = axes[1]
region = "Ross"
reg_trans = [vol_transp_var.where((lon_along_contour>-60)&(lon_along_contour<0),drop=True) for vol_transp_var in vol_transp]
for a,i in enumerate([0,3,4]):
    reg_trans_y = reg_trans[i].sel(isopycnal_bins = slice(32.56,None)).sum("isopycnal_bins").sum('contour_index')/1e6
    ax.plot(hov_time_datetime,reg_trans_y[:endmonth[i]], color = colors[a], alpha = alpha[a])
ax.plot(hov_time_datetime,vol_transp_bench_weddell_mean_48, color = "grey", alpha = 0.8)
ax.fill_between(hov_time_datetime,vol_transp_bench_weddell_mean_48 - vol_transp_bench_weddell_std_48,vol_transp_bench_weddell_mean_48 + vol_transp_bench_weddell_std_48 , color = "grey", alpha = 0.2)


ax.set_xlabel("Months")
ax.grid()
ax.set_xticks(range(0,54,6))
ax.set_yticks(range(0,3,1))

ax.set_xlim(0,47)
# plt.ylabel("cross 1000m DSW transport")
# Out:
# (0.0, 47.0)

# %%
ds_iaf = xr.open_dataset("/g/data/oz91/ma3822/ZW3/data/ds_iaf.nc")
ds_iaf
# Out:
# <xarray.Dataset>
# Dimensions:                   (time: 59)
# Coordinates:
#   * time                      (time) int64 1959 1960 1961 ... 2015 2016 2017
# Data variables:
#     PC1_runningmean           (time) float32 ...
#     PC2_runningmean           (time) float32 ...
#     Weddell_SWMT_runningmean  (time) float64 ...
#     Ross_SWMT_runningmean     (time) float64 ...

# %%
da_swmt_shelf = xr.open_dataarray("/g/data/oz91/ma3822/ZW3/data/swmt_yr12_32_66.nc")

# %%
import matplotlib.gridspec as gridspec

f = plt.figure(figsize = (12,6))

# Create a gridspec with custom spacing
gs = gridspec.GridSpec(2, 2, 
                       height_ratios=[1, 1],  # Equal heights for all rows
                       hspace=0.3)  # Overall vertical spacing

# Create a gridspec with custom spacing
gs2 = gridspec.GridSpec(2, 3, 
                       height_ratios=[1, 1],  # Equal heights for all rows
                       hspace=0.3)  # Overall vertical spacing

# Create subplots using gridspec
ax1 = plt.subplot(gs2[0, 0])
ax2 = plt.subplot(gs[0, 1])


ax3 = plt.subplot(gs[1,:])


ax = ax1
ax.contour(shelf_mask.xt_ocean, shelf_mask.yt_ocean, shelf_mask, [0, 1],
           colors='k', alpha =0.8)

norm = col.Normalize(vmin=0, vmax=2.5)


cs = ax.pcolormesh(da_agebottom.xt_ocean, da_agebottom.yt_ocean, da_agebottom.sel(scenario = "PC2Plus")/maxage - da_agebottom.sel(scenario = "Neutral")/maxage,
                       cmap=cm.cm.balance, vmin=-0.1, vmax=0.1)

swmt_loc = da_swmt_shelf
swmt_loc = swmt_loc.where(swmt_loc>0)

plot_swmt = ax.pcolormesh(da_swmt_shelf.xt_ocean, da_swmt_shelf.yt_ocean, swmt_loc.sel(scenario = "PC2Plus"),
                           cmap=cm.cm.matter, vmin = 0, vmax = 2.5*1e-5)
land = xr.where(np.isnan(bathy.rename('land')), 1, np.nan)
land.plot(ax = ax,add_colorbar =False, cmap = "Greys")
lim_regional("Weddell", ax,bathy)
ax.set_xlabel(None)
ax.set_ylabel(None)

# ax.set_ylabel("Latitude (°)")
# ax.set_xlabel("Longitude (°)")

# cbar1 = plt.colorbar(cs, ax = ax1)
# cbar1.set_label(r'Age Bottom Anomaly (years)', rotation=270, labelpad=20, size = 12)
# cbar1.set_label(r'Age Bottom Anomaly (years)',  size = 12)

# pos1 = ax1.get_position()
# Create small axes for SWMT colorbar (positioned in upper left of ax1)
# cbar_ax_swmt = f.add_axes([pos1.x0 + 0.22, pos1.y1 - 0.14, 0.05, 0.01])  # [left, bottom, width, height]
# cbar_swmt = plt.colorbar(plot_swmt, cax=cbar_ax_swmt)
# cbar_swmt = plt.colorbar(plot_swmt, ax = ax1)
# cbar_swmt.set_label(r'Surface Transformation (m/s)',size = 12)

ax = ax2

year_s = 25
ds_iaf.Weddell_SWMT_runningmean.plot(ax = ax2,color = 'k')
ax.set_ylabel('Weddell_SWMT');
axdup = ax.twinx()
ds_iaf.PC2_runningmean.plot(ax = axdup, color = "purple")
ds_iaf.PC1_runningmean.plot(ax = axdup, color = "green", alpha = 0.2)

# axdup.plot(PC2.year[1:-5],PC2_rm, color = "purple")
# axdup.plot(PC2.year[1:-5],PC1_rm, color = "green", alpha = 0.2)

# axdup.set_ylabel("ZW3 index", color = "purple")
# ax.set_ylabel("SWMT Weddell sea (Sv)", color = "k")
ax.set_xlabel(None)
ax.set_ylabel(None)

ax.grid()

ax = ax3
hov_time_datetime = range(0,48)


colors = ["k", "r", "b"]
alpha = [1,1,1]
endmonth = [48,36,36,48,48]
reg = (lon_along_contour>-200)&(lon_along_contour<-160)

region = "Weddell"
reg_trans = [vol_transp_var.where((lon_along_contour>-60)&(lon_along_contour<0),drop=True) for vol_transp_var in vol_transp]
for a,i in enumerate([0,3,4]):
    reg_trans_y = reg_trans[i].sel(isopycnal_bins = slice(32.56,None)).sum("isopycnal_bins").sum('contour_index')/1e6
    ax.plot(hov_time_datetime,reg_trans_y[:endmonth[i]], color = colors[a], alpha = alpha[a])
ax.plot(hov_time_datetime,vol_transp_bench_weddell_mean_48, color = "grey", alpha = 0.8)
ax.fill_between(hov_time_datetime,vol_transp_bench_weddell_mean_48 - vol_transp_bench_weddell_std_48,vol_transp_bench_weddell_mean_48 + vol_transp_bench_weddell_std_48 , color = "grey", alpha = 0.2)


# ax.set_xlabel("Months")
ax.grid()
ax.set_xticks(range(0,54,6))
ax.set_yticks(range(0,3,1))

ax.set_xlim(0,47)
plt.tight_layout()
# plt.subplots_adjust(hspace=0.15)  # Reduce vertical spacing between subplots
axdup.set_ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
ds_iaf.Weddell_SWMT_runningmean.plot(color = 'k')

# %%
da_swmt_shelf = xr.open_dataarray("/g/data/oz91/ma3822/ZW3/data/swmt_yr12_32_6.nc")

# %%
import matplotlib.gridspec as gridspec

f = plt.figure(figsize = (12,6))

# Create a gridspec with custom spacing
gs = gridspec.GridSpec(2, 2, 
                       height_ratios=[1, 1],  # Equal heights for all rows
                       hspace=0.3)  # Overall vertical spacing

# Create a gridspec with custom spacing
gs2 = gridspec.GridSpec(2, 3, 
                       height_ratios=[1, 1],  # Equal heights for all rows
                       hspace=0.3)  # Overall vertical spacing

# Create subplots using gridspec
ax1 = plt.subplot(gs2[0, 0])
ax2 = plt.subplot(gs[0, 1])


ax3 = plt.subplot(gs[1,:])


ax = ax1
ax.contour(shelf_mask.xt_ocean, shelf_mask.yt_ocean, shelf_mask, [0, 1],
           colors='k', alpha =0.8)

norm = col.Normalize(vmin=0, vmax=2.5)


cs = ax.pcolormesh(da_agebottom.xt_ocean, da_agebottom.yt_ocean, da_agebottom.sel(scenario = "PC2Plus")/maxage - da_agebottom.sel(scenario = "Neutral")/maxage,
                       cmap=cm.cm.balance, vmin=-0.1, vmax=0.1)

swmt_loc = da_swmt_shelf
swmt_loc = swmt_loc.where(swmt_loc>0)

plot_swmt = ax.pcolormesh(da_swmt_shelf.xt_ocean, da_swmt_shelf.yt_ocean, swmt_loc.sel(scenario = "PC2Plus"),
                           cmap=cm.cm.matter, vmin = 0, vmax = 2.5*1e-5)
land = xr.where(np.isnan(bathy.rename('land')), 1, np.nan)
land.plot(ax = ax,add_colorbar =False, cmap = "Greys")
lim_regional("Weddell", ax,bathy)
ax.set_xlabel(None)
ax.set_ylabel(None)

# ax.set_ylabel("Latitude (°)")
# ax.set_xlabel("Longitude (°)")

# cbar1 = plt.colorbar(cs, ax = ax1)
# cbar1.set_label(r'Age Bottom Anomaly (years)', rotation=270, labelpad=20, size = 12)
# cbar1.set_label(r'Age Bottom Anomaly (years)',  size = 12)

# pos1 = ax1.get_position()
# Create small axes for SWMT colorbar (positioned in upper left of ax1)
# cbar_ax_swmt = f.add_axes([pos1.x0 + 0.22, pos1.y1 - 0.14, 0.05, 0.01])  # [left, bottom, width, height]
# cbar_swmt = plt.colorbar(plot_swmt, cax=cbar_ax_swmt)
# cbar_swmt = plt.colorbar(plot_swmt, ax = ax1)
# cbar_swmt.set_label(r'Surface Transformation (m/s)',size = 12)

ax = ax2

year_s = 25
ds_iaf.Weddell_SWMT_runningmean.plot(ax = ax2,color = 'k')
ax.set_ylabel('Weddell_SWMT');
axdup = ax.twinx()
ds_iaf.PC2_runningmean.plot(ax = axdup, color = "purple")
ds_iaf.PC1_runningmean.plot(ax = axdup, color = "green", alpha = 0.2)

# axdup.plot(PC2.year[1:-5],PC2_rm, color = "purple")
# axdup.plot(PC2.year[1:-5],PC1_rm, color = "green", alpha = 0.2)

# axdup.set_ylabel("ZW3 index", color = "purple")
# ax.set_ylabel("SWMT Weddell sea (Sv)", color = "k")
ax.set_xlabel(None)
ax.set_ylabel(None)

ax.grid()

ax = ax3
hov_time_datetime = range(0,48)


colors = ["k", "r", "b"]
alpha = [1,1,1]
endmonth = [48,36,36,48,48]
reg = (lon_along_contour>-200)&(lon_along_contour<-160)

region = "Weddell"
reg_trans = [vol_transp_var.where((lon_along_contour>-60)&(lon_along_contour<0),drop=True) for vol_transp_var in vol_transp]
for a,i in enumerate([0,3,4]):
    reg_trans_y = reg_trans[i].sel(isopycnal_bins = slice(32.56,None)).sum("isopycnal_bins").sum('contour_index')/1e6
    ax.plot(hov_time_datetime,reg_trans_y[:endmonth[i]], color = colors[a], alpha = alpha[a])
ax.plot(hov_time_datetime,vol_transp_bench_weddell_mean_48, color = "grey", alpha = 0.8)
ax.fill_between(hov_time_datetime,vol_transp_bench_weddell_mean_48 - vol_transp_bench_weddell_std_48,vol_transp_bench_weddell_mean_48 + vol_transp_bench_weddell_std_48 , color = "grey", alpha = 0.2)


# ax.set_xlabel("Months")
ax.grid()
ax.set_xticks(range(0,54,6))
ax.set_yticks(range(0,3,1))

ax.set_xlim(0,47)
plt.tight_layout()
# plt.subplots_adjust(hspace=0.15)  # Reduce vertical spacing between subplots
axdup.set_ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
da_swmt_shelf = xr.open_dataarray("/g/data/oz91/ma3822/ZW3/data/swmt_sig0_yr12.nc").isel(isopycnal_bins = 8)
import matplotlib.gridspec as gridspec

f = plt.figure(figsize = (12,6))

# Create a gridspec with custom spacing
gs = gridspec.GridSpec(2, 2, 
                       height_ratios=[1, 1],  # Equal heights for all rows
                       hspace=0.3)  # Overall vertical spacing

# Create a gridspec with custom spacing
gs2 = gridspec.GridSpec(2, 3, 
                       height_ratios=[1, 1],  # Equal heights for all rows
                       hspace=0.3)  # Overall vertical spacing

# Create subplots using gridspec
ax1 = plt.subplot(gs2[0, 0])
ax2 = plt.subplot(gs[0, 1])


ax3 = plt.subplot(gs[1,:])


ax = ax1
ax.contour(shelf_mask.xt_ocean, shelf_mask.yt_ocean, shelf_mask, [0, 1],
           colors='k', alpha =0.8)

norm = col.Normalize(vmin=0, vmax=2.5)


cs = ax.pcolormesh(da_agebottom.xt_ocean, da_agebottom.yt_ocean, da_agebottom.sel(scenario = "PC2Plus")/maxage - da_agebottom.sel(scenario = "Neutral")/maxage,
                       cmap=cm.cm.balance, vmin=-0.1, vmax=0.1)

swmt_loc = da_swmt_shelf
swmt_loc = swmt_loc.where(swmt_loc>0)

plot_swmt = ax.pcolormesh(da_swmt_shelf.xt_ocean, da_swmt_shelf.yt_ocean, swmt_loc.sel(scenario = "PC2Plus"),
                           cmap=cm.cm.matter, vmin = 0, vmax = 2.5*1e-5)
land = xr.where(np.isnan(bathy.rename('land')), 1, np.nan)
land.plot(ax = ax,add_colorbar =False, cmap = "Greys")
lim_regional("Weddell", ax,bathy)
ax.set_xlabel(None)
ax.set_ylabel(None)

# ax.set_ylabel("Latitude (°)")
# ax.set_xlabel("Longitude (°)")

# cbar1 = plt.colorbar(cs, ax = ax1)
# cbar1.set_label(r'Age Bottom Anomaly (years)', rotation=270, labelpad=20, size = 12)
# cbar1.set_label(r'Age Bottom Anomaly (years)',  size = 12)

# pos1 = ax1.get_position()
# Create small axes for SWMT colorbar (positioned in upper left of ax1)
# cbar_ax_swmt = f.add_axes([pos1.x0 + 0.22, pos1.y1 - 0.14, 0.05, 0.01])  # [left, bottom, width, height]
# cbar_swmt = plt.colorbar(plot_swmt, cax=cbar_ax_swmt)
# cbar_swmt = plt.colorbar(plot_swmt, ax = ax1)
# cbar_swmt.set_label(r'Surface Transformation (m/s)',size = 12)

ax = ax2

year_s = 25
ds_iaf.Weddell_SWMT_runningmean.plot(ax = ax2,color = 'k')
ax.set_ylabel('Weddell_SWMT');
axdup = ax.twinx()
ds_iaf.PC2_runningmean.plot(ax = axdup, color = "purple")
ds_iaf.PC1_runningmean.plot(ax = axdup, color = "green", alpha = 0.2)

# axdup.plot(PC2.year[1:-5],PC2_rm, color = "purple")
# axdup.plot(PC2.year[1:-5],PC1_rm, color = "green", alpha = 0.2)

# axdup.set_ylabel("ZW3 index", color = "purple")
# ax.set_ylabel("SWMT Weddell sea (Sv)", color = "k")
ax.set_xlabel(None)
ax.set_ylabel(None)

ax.grid()

ax = ax3
hov_time_datetime = range(0,48)


colors = ["k", "r", "b"]
alpha = [1,1,1]
endmonth = [48,36,36,48,48]
reg = (lon_along_contour>-200)&(lon_along_contour<-160)

region = "Weddell"
reg_trans = [vol_transp_var.where((lon_along_contour>-60)&(lon_along_contour<0),drop=True) for vol_transp_var in vol_transp]
for a,i in enumerate([0,3,4]):
    reg_trans_y = reg_trans[i].sel(isopycnal_bins = slice(32.56,None)).sum("isopycnal_bins").sum('contour_index')/1e6
    ax.plot(hov_time_datetime,reg_trans_y[:endmonth[i]], color = colors[a], alpha = alpha[a])
ax.plot(hov_time_datetime,vol_transp_bench_weddell_mean_48, color = "grey", alpha = 0.8)
ax.fill_between(hov_time_datetime,vol_transp_bench_weddell_mean_48 - vol_transp_bench_weddell_std_48,vol_transp_bench_weddell_mean_48 + vol_transp_bench_weddell_std_48 , color = "grey", alpha = 0.2)


# ax.set_xlabel("Months")
ax.grid()
ax.set_xticks(range(0,54,6))
ax.set_yticks(range(0,3,1))

ax.set_xlim(0,47)
plt.tight_layout()
# plt.subplots_adjust(hspace=0.15)  # Reduce vertical spacing between subplots
axdup.set_ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
da_swmt_shelf.isopycnal_bins
# Out:
# <xarray.DataArray 'isopycnal_bins' ()>
# array(27.87)
# Coordinates:
#     isopycnal_bins  float64 27.87

# %%
da_swmt_shelf = xr.open_dataarray("/g/data/oz91/ma3822/ZW3/data/swmt_sig0_yr12.nc")
da_swmt_shelf.isopycnal_bins - .5*(
    da_swmt_shelf.isopycnal_bins[1]-da_swmt_shelf.isopycnal_bins[0])
# Out:
# <xarray.DataArray 'isopycnal_bins' (isopycnal_bins: 20)>
# array([27.7 , 27.72, 27.74, 27.76, 27.78, 27.8 , 27.82, 27.84, 27.86,
#        27.88, 27.9 , 27.92, 27.94, 27.96, 27.98, 28.  , 28.02, 28.04,
#        28.06, 28.08])
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 27.71 27.73 27.75 ... 28.07 28.09
